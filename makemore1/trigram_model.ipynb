# %%
words = open('names.txt', 'r').read().splitlines()

# %%
len(words)
# Out:
# 32033

# %%
# bigram dictionary

b = {}

for w in words:
    chs = ['.'] + list(w) + ['.']
    for ch1, ch2 in zip(chs,chs[1:]):
        bigram = (ch1, ch2)
        b[bigram] = b.get(bigram, 0) +1

len(b)
# Out:
# 627

# %%
# trigram

t = {}

for w in words:
    chs = ['.'] + list(w) + ['.']
    for ch1, ch2, ch3 in zip(chs, chs[1:], chs[2:]):
        
        trigram = (ch1,ch2,ch3)
        t[trigram] = t.get(trigram,0) +1
        
len(t)
# Out:
# 6037

# %%
len(t)
# Out:
# 6037

# %%
sorted(t.items(),key=lambda kv: -kv[1])
# Out:
# [(('a', 'h', '.'), 1714),
#  (('n', 'a', '.'), 1673),
#  (('a', 'n', '.'), 1509),
#  (('o', 'n', '.'), 1503),
#  (('.', 'm', 'a'), 1453),
#  (('.', 'j', 'a'), 1255),
#  (('.', 'k', 'a'), 1254),
#  (('e', 'n', '.'), 1217),
#  (('l', 'y', 'n'), 976),
#  (('y', 'n', '.'), 953),
#  (('a', 'r', 'i'), 950),
#  (('i', 'a', '.'), 903),
#  (('i', 'e', '.'), 858),
#  (('a', 'n', 'n'), 825),
#  (('e', 'l', 'l'), 822),
#  (('a', 'n', 'a'), 804),
#  (('i', 'a', 'n'), 790),
#  (('m', 'a', 'r'), 776),
#  (('i', 'n', '.'), 766),
#  (('e', 'l', '.'), 727),
#  (('y', 'a', '.'), 716),
#  (('a', 'n', 'i'), 703),
#  (('.', 'd', 'a'), 700),
#  (('l', 'a', '.'), 684),
#  (('e', 'r', '.'), 683),
#  (('i', 'y', 'a'), 669),
#  (('l', 'a', 'n'), 647),
#  (('.', 'b', 'r'), 646),
#  (('n', 'n', 'a'), 633),
#  (('.', 'a', 'l'), 632),
#  (('.', 'c', 'a'), 628),
#  (('r', 'a', '.'), 627),
#  (('n', 'i', '.'), 625),
#  (('.', 'a', 'n'), 623),
#  (('n', 'n', '.'), 619),
#  (('n', 'e', '.'), 607),
#  (('e', 'e', '.'), 605),
#  (('e', 'y', '.'), 602),
#  (('.', 'k', 'e'), 601),
#  (('a', 'l', 'e'), 601),
#  (('.', 's', 'a'), 595),
#  (('a', 'l', 'i'), 575),
#  (('s', 'h', 'a'), 562),
#  (('e', 'l', 'i'), 537),
#  (('.', 'd', 'e'), 524),
#  (('l', 'i', 'a'), 518),
#  (('l', 'e', 'e'), 517),
#  (('y', 'n', 'n'), 516),
#  (('y', 'a', 'h'), 511),
#  (('.', 'h', 'a'), 505),
#  (('l', 'i', 'n'), 505),
#  (('r', 'i', 'a'), 499),
#  (('.', 'e', 'l'), 488),
#  (('a', 'y', 'l'), 483),
#  (('.', 'a', 'r'), 482),
#  (('y', 'a', 'n'), 479),
#  (('.', 'r', 'a'), 472),
#  (('.', 'n', 'a'), 470),
#  (('h', 'a', 'n'), 469),
#  (('.', 'l', 'a'), 463),
#  (('i', 'a', 'h'), 461),
#  (('.', 'z', 'a'), 456),
#  (('r', 'i', '.'), 452),
#  (('l', 'e', 'y'), 443),
#  (('.', 's', 'h'), 434),
#  (('a', 'm', 'a'), 431),
#  (('.', 'j', 'o'), 429),
#  (('.', 't', 'a'), 424),
#  (('.', 'j', 'e'), 403),
#  (('l', 'e', 'i'), 401),
#  (('i', 'e', 'l'), 395),
#  (('r', 'i', 'e'), 394),
#  (('.', 'm', 'i'), 393),
#  (('a', 'n', 'd'), 392),
#  (('a', 'y', 'a'), 389),
#  (('.', 'a', 'm'), 384),
#  (('l', 'e', 'n'), 383),
#  (('.', 'r', 'o'), 382),
#  (('y', 'l', 'a'), 381),
#  (('i', 'n', 'a'), 379),
#  (('t', 'o', 'n'), 377),
#  (('a', 'r', 'a'), 371),
#  (('.', 'a', 'd'), 366),
#  (('.', 'l', 'e'), 366),
#  (('l', 'e', '.'), 362),
#  (('r', 'i', 's'), 360),
#  (('a', 'm', 'i'), 355),
#  (('e', 'l', 'y'), 353),
#  (('a', 'l', 'a'), 353),
#  (('.', 'c', 'h'), 352),
#  (('s', 'o', 'n'), 341),
#  (('l', 'l', 'a'), 337),
#  (('l', 'l', 'e'), 331),
#  (('h', 'a', 'r'), 329),
#  (('d', 'e', 'n'), 318),
#  (('a', 'l', 'y'), 310),
#  (('e', 'l', 'a'), 308),
#  (('a', 'v', 'i'), 306),
#  (('y', 'l', 'e'), 303),
#  (('i', 'g', 'h'), 290),
#  (('i', 'o', 'n'), 290),
#  (('.', 'e', 'm'), 288),
#  (('a', 'r', 'l'), 287),
#  (('i', 's', '.'), 287),
#  (('a', 'e', 'l'), 287),
#  (('l', 'i', 'e'), 285),
#  (('h', 'a', '.'), 284),
#  (('.', 'm', 'e'), 284),
#  (('r', 'e', 'n'), 281),
#  (('u', 's', '.'), 280),
#  (('i', 'l', 'a'), 279),
#  (('e', 'n', 'a'), 279),
#  (('e', 'i', 'g'), 279),
#  (('a', 's', 'h'), 276),
#  (('m', 'a', 'n'), 274),
#  (('l', 'l', 'i'), 271),
#  (('l', 'y', '.'), 270),
#  (('.', 'l', 'i'), 269),
#  (('.', 'r', 'e'), 268),
#  (('e', 'r', 'i'), 268),
#  (('n', 'n', 'e'), 261),
#  (('a', 'i', 'l'), 259),
#  (('m', 'i', 'l'), 259),
#  (('.', 'c', 'o'), 255),
#  (('b', 'r', 'i'), 254),
#  (('r', 'a', 'y'), 254),
#  (('.', 'b', 'e'), 253),
#  (('s', 'a', '.'), 253),
#  (('k', 'e', 'n'), 252),
#  (('.', 'k', 'i'), 250),
#  (('i', 'r', 'a'), 248),
#  (('r', 'a', 'n'), 248),
#  (('i', 'r', '.'), 248),
#  (('.', 'y', 'a'), 246),
#  (('.', 'a', 'v'), 243),
#  (('i', 'n', 'e'), 241),
#  (('e', 'n', 'n'), 240),
#  (('.', 'k', 'h'), 240),
#  (('v', 'a', 'n'), 237),
#  (('c', 'h', 'a'), 236),
#  (('g', 'h', '.'), 235),
#  (('c', 'e', '.'), 234),
#  (('l', 'a', 'y'), 234),
#  (('r', 'i', 'n'), 234),
#  (('r', 'e', '.'), 231),
#  (('.', 'k', 'y'), 229),
#  (('a', 'r', '.'), 228),
#  (('s', 'e', '.'), 228),
#  (('i', 's', 'h'), 227),
#  (('a', 'm', 'e'), 226),
#  (('.', 'n', 'i'), 226),
#  (('k', 'a', 'i'), 226),
#  (('l', 'a', 'h'), 224),
#  (('a', 'n', 'e'), 224),
#  (('n', 'i', 'e'), 223),
#  (('r', 'a', 'h'), 222),
#  (('l', 'i', '.'), 221),
#  (('n', 'n', 'i'), 221),
#  (('o', 'r', 'i'), 220),
#  (('e', 'l', 'e'), 219),
#  (('k', 'a', 'r'), 218),
#  (('d', 'e', 'l'), 217),
#  (('k', 'a', 'y'), 215),
#  (('j', 'a', 'y'), 212),
#  (('i', 'l', 'l'), 211),
#  (('m', 'a', 'l'), 210),
#  (('k', 'a', '.'), 210),
#  (('m', 'e', 'r'), 209),
#  (('y', 'l', 'i'), 209),
#  (('.', 't', 'r'), 209),
#  (('r', 'i', 'c'), 209),
#  (('l', 'i', 's'), 208),
#  (('.', 'a', 'a'), 207),
#  (('d', 'a', 'n'), 207),
#  (('r', 'e', 'e'), 205),
#  (('i', 'l', 'y'), 203),
#  (('e', 't', 't'), 203),
#  (('d', 'a', 'l'), 203),
#  (('l', 'l', '.'), 203),
#  (('b', 'r', 'a'), 203),
#  (('o', 'r', 'a'), 202),
#  (('b', 'e', 'l'), 201),
#  (('r', 'y', '.'), 201),
#  (('.', 'r', 'i'), 201),
#  (('m', 'o', 'n'), 201),
#  (('e', 'e', 'n'), 200),
#  (('a', 'r', 'e'), 198),
#  (('i', 'l', 'e'), 197),
#  (('t', 'a', '.'), 197),
#  (('d', 'a', '.'), 197),
#  (('e', 'a', 'n'), 196),
#  (('a', 'l', 'l'), 196),
#  (('r', 'o', 's'), 196),
#  (('a', 'r', 'y'), 195),
#  (('a', 'd', 'e'), 194),
#  (('.', 'a', 's'), 194),
#  (('o', 'n', 'n'), 194),
#  (('c', 'a', 'r'), 193),
#  (('n', 'y', '.'), 192),
#  (('.', 'k', 'o'), 192),
#  (('a', 'r', 'r'), 192),
#  (('.', 'a', 'b'), 190),
#  (('a', 'd', 'i'), 190),
#  (('b', 'r', 'e'), 189),
#  (('a', 'i', 'r'), 189),
#  (('a', 'm', '.'), 189),
#  (('o', 'n', 'i'), 189),
#  (('m', 'e', 'l'), 188),
#  (('.', 'l', 'o'), 186),
#  (('n', 'a', 'h'), 185),
#  (('n', 'd', 'r'), 184),
#  (('a', 'i', '.'), 183),
#  (('.', 's', 'e'), 182),
#  (('r', 'r', 'i'), 182),
#  (('.', 't', 'e'), 181),
#  (('i', 'l', 'i'), 180),
#  (('e', 'y', 'a'), 179),
#  (('t', 'h', '.'), 178),
#  (('.', 'j', 'u'), 178),
#  (('a', 'y', 'd'), 178),
#  (('l', 'a', 'i'), 177),
#  (('a', 'n', 't'), 177),
#  (('a', 'i', 'n'), 177),
#  (('t', 'e', '.'), 175),
#  (('.', 'p', 'a'), 175),
#  (('i', 'k', 'a'), 175),
#  (('a', 'n', 'y'), 175),
#  (('a', 'l', '.'), 175),
#  (('m', 'a', '.'), 174),
#  (('a', 'a', 'n'), 174),
#  (('a', 'b', 'e'), 173),
#  (('l', 'e', 'a'), 173),
#  (('.', 'a', 'y'), 173),
#  (('a', 's', '.'), 173),
#  (('.', 's', 'i'), 172),
#  (('m', 'i', 'r'), 172),
#  (('s', 'i', 'a'), 171),
#  (('k', 'h', 'a'), 171),
#  (('e', 'r', 'e'), 170),
#  (('s', 'h', 'i'), 170),
#  (('.', 'b', 'a'), 169),
#  (('t', 'h', 'a'), 168),
#  (('e', 'n', 'i'), 168),
#  (('.', 'm', 'o'), 168),
#  (('k', 'a', 'l'), 168),
#  (('r', 'o', 'n'), 168),
#  (('a', 'v', 'e'), 166),
#  (('o', 's', 'e'), 166),
#  (('s', 's', 'a'), 166),
#  (('.', 'g', 'r'), 165),
#  (('s', 't', 'o'), 165),
#  (('.', 'n', 'e'), 164),
#  (('a', 'd', 'a'), 164),
#  (('r', 'e', 'y'), 163),
#  (('a', 'y', '.'), 163),
#  (('.', 'l', 'u'), 162),
#  (('d', 'r', 'i'), 162),
#  (('a', 'v', 'a'), 161),
#  (('.', 'v', 'i'), 161),
#  (('e', 'm', 'i'), 160),
#  (('v', 'e', 'r'), 160),
#  (('s', 't', 'i'), 159),
#  (('s', 'a', 'n'), 159),
#  (('.', 'f', 'a'), 158),
#  (('e', 'a', '.'), 158),
#  (('a', 's', 'i'), 157),
#  (('.', 'n', 'o'), 156),
#  (('i', 's', 't'), 156),
#  (('.', 'e', 'v'), 154),
#  (('s', 't', 'e'), 154),
#  (('.', 'a', 'i'), 154),
#  (('t', 'a', 'l'), 153),
#  (('l', 'a', 'r'), 153),
#  (('m', 'a', 'y'), 153),
#  (('e', 's', 's'), 153),
#  (('h', 'a', 'l'), 153),
#  (('d', 'a', 'r'), 153),
#  (('h', 'a', 'm'), 153),
#  (('.', 's', 'o'), 152),
#  (('.', 'a', 'u'), 152),
#  (('b', 'e', 'r'), 152),
#  (('.', 'a', 'z'), 152),
#  (('e', 'n', 'e'), 151),
#  (('k', 'a', 'm'), 151),
#  (('.', 'h', 'e'), 151),
#  (('j', 'a', 'm'), 151),
#  (('s', 'h', '.'), 149),
#  (('d', 'e', 'r'), 149),
#  (('o', 'r', '.'), 148),
#  (('v', 'i', 'n'), 148),
#  (('v', 'i', 'a'), 147),
#  (('e', 's', 't'), 147),
#  (('l', 'o', 'n'), 147),
#  (('o', 'n', 'a'), 147),
#  (('a', 'e', '.'), 147),
#  (('r', 'l', 'e'), 146),
#  (('r', 'i', 'o'), 146),
#  (('n', 'e', 'l'), 145),
#  (('a', 'i', 's'), 145),
#  (('e', 'r', 'a'), 145),
#  (('n', 'l', 'e'), 143),
#  (('r', 'e', 'l'), 143),
#  (('h', 'i', '.'), 143),
#  (('i', 's', 'a'), 142),
#  (('e', 'v', 'e'), 142),
#  (('t', 'i', 'n'), 142),
#  (('a', 't', 'h'), 142),
#  (('d', 'o', 'n'), 142),
#  (('s', 'e', 'n'), 142),
#  (('m', 'i', 'n'), 141),
#  (('.', 's', 'u'), 141),
#  (('k', 'e', 'l'), 141),
#  (('t', 'a', 'n'), 141),
#  (('n', 'i', 'a'), 141),
#  (('r', 'y', 'n'), 140),
#  (('j', 'a', 'n'), 140),
#  (('n', 'a', 'l'), 140),
#  (('e', 'r', 'r'), 140),
#  (('e', 'm', 'a'), 140),
#  (('s', 't', 'a'), 139),
#  (('i', 'o', '.'), 139),
#  (('s', 'l', 'e'), 138),
#  (('a', 'i', 'd'), 138),
#  (('e', 's', '.'), 138),
#  (('l', 'o', 'r'), 137),
#  (('m', 'a', 'd'), 136),
#  (('s', 'a', 'm'), 136),
#  (('.', 'g', 'a'), 136),
#  (('r', 'i', 'y'), 136),
#  (('.', 's', 't'), 135),
#  (('i', 'e', 'r'), 135),
#  (('.', 'z', 'e'), 135),
#  (('j', 'a', 'h'), 135),
#  (('k', 'i', 'n'), 134),
#  (('l', 'i', 'l'), 133),
#  (('e', 'v', 'a'), 133),
#  (('h', 'a', 'y'), 133),
#  (('t', 'e', 'r'), 133),
#  (('a', 'y', 's'), 133),
#  (('.', 't', 'y'), 133),
#  (('h', 'e', 'r'), 132),
#  (('r', 'a', 'i'), 132),
#  (('e', 'o', 'n'), 131),
#  (('.', 'd', 'i'), 130),
#  (('c', 'h', 'e'), 130),
#  (('a', 'c', 'e'), 129),
#  (('i', 'c', 'k'), 129),
#  (('d', 'y', '.'), 128),
#  (('.', 'g', 'i'), 128),
#  (('e', 'm', '.'), 128),
#  (('y', 'o', 'n'), 128),
#  (('r', 'a', 'e'), 127),
#  (('n', 'c', 'e'), 127),
#  (('i', 's', 'e'), 126),
#  (('n', 'd', '.'), 126),
#  (('.', 'p', 'r'), 125),
#  (('i', 'n', 'g'), 125),
#  (('.', 'i', 's'), 124),
#  (('m', 'i', '.'), 124),
#  (('i', 't', 'h'), 124),
#  (('l', 'l', 'y'), 124),
#  (('o', 'l', 'a'), 124),
#  (('u', 'r', 'i'), 123),
#  (('a', 'z', 'a'), 123),
#  (('j', 'e', 'r'), 123),
#  (('i', 'r', 'e'), 122),
#  (('i', 's', 's'), 122),
#  (('t', 't', 'e'), 121),
#  (('.', 'v', 'a'), 121),
#  (('c', 'a', 'l'), 121),
#  (('a', 'k', 'a'), 121),
#  (('z', 'a', 'r'), 121),
#  (('y', 'd', 'e'), 121),
#  (('v', 'i', '.'), 121),
#  (('g', 'r', 'a'), 120),
#  (('m', 'a', 'i'), 120),
#  (('c', 'k', '.'), 120),
#  (('i', 'l', '.'), 119),
#  (('h', 'a', 'i'), 119),
#  (('e', 'n', 'd'), 119),
#  (('v', 'e', 'n'), 119),
#  (('.', 'd', 'o'), 119),
#  (('r', 'i', 't'), 119),
#  (('v', 'o', 'n'), 119),
#  (('.', 'l', 'y'), 118),
#  (('r', 'y', 'a'), 118),
#  (('l', 'i', 'y'), 117),
#  (('s', 'e', 'l'), 117),
#  (('i', 'm', 'a'), 117),
#  (('b', 'r', 'y'), 116),
#  (('e', 't', 'h'), 114),
#  (('d', 'r', 'e'), 113),
#  (('n', 'a', 'y'), 113),
#  (('k', 'a', 's'), 113),
#  (('t', 'e', 'n'), 113),
#  (('h', 'e', 'l'), 112),
#  (('o', 'r', 'e'), 112),
#  (('.', 't', 'o'), 112),
#  (('a', 't', 'a'), 111),
#  (('.', 'r', 'y'), 111),
#  (('e', 'i', 'l'), 111),
#  (('r', 'a', 'l'), 111),
#  (('h', 'r', 'i'), 111),
#  (('a', 'h', 'a'), 111),
#  (('t', 'o', 'r'), 110),
#  (('.', 'g', 'e'), 110),
#  (('a', 'n', 'g'), 110),
#  (('i', 'd', 'e'), 110),
#  (('m', 'a', 'k'), 109),
#  (('.', 't', 'i'), 109),
#  (('n', 'd', 'e'), 109),
#  (('a', 'u', 'r'), 108),
#  (('.', 'r', 'u'), 108),
#  (('d', 'y', 'n'), 108),
#  (('n', 'i', 'y'), 108),
#  (('s', 'h', 'e'), 108),
#  (('t', 'r', 'i'), 107),
#  (('n', 'i', 's'), 107),
#  (('n', 'o', '.'), 107),
#  (('e', 't', '.'), 106),
#  (('d', 'i', 'e'), 106),
#  (('t', 'h', 'e'), 106),
#  (('h', 'e', 'n'), 106),
#  (('a', 'd', '.'), 106),
#  (('a', 'i', 'a'), 105),
#  (('j', 'a', 'i'), 105),
#  (('.', 'o', 'l'), 104),
#  (('k', 'y', 'l'), 104),
#  (('d', 'i', '.'), 104),
#  (('n', 'a', 'n'), 104),
#  (('t', 'r', 'e'), 104),
#  (('l', 'o', '.'), 104),
#  (('r', 'a', 'c'), 103),
#  (('a', 'r', 'o'), 103),
#  (('i', 'n', 'n'), 103),
#  (('.', 'm', 'y'), 103),
#  (('s', 's', 'i'), 103),
#  (('t', 't', '.'), 102),
#  (('c', 'o', 'r'), 102),
#  (('a', 's', 't'), 102),
#  (('a', 'r', 't'), 102),
#  (('n', 'a', 'i'), 102),
#  (('n', 'o', 'r'), 101),
#  (('n', 'a', 't'), 101),
#  (('e', 'r', 'l'), 101),
#  (('l', 'e', 's'), 101),
#  (('a', 'm', 'o'), 101),
#  (('a', 'h', 'i'), 101),
#  (('a', 'i', 'y'), 101),
#  (('o', 'n', 't'), 101),
#  (('e', 'm', 'm'), 100),
#  (('t', 'y', 'n'), 100),
#  (('h', 'a', 'd'), 99),
#  (('g', 'a', 'n'), 99),
#  (('.', 't', 'h'), 99),
#  (('i', 't', 'a'), 99),
#  (('l', 'y', 'a'), 99),
#  (('a', 'n', 's'), 99),
#  (('a', 'k', 'i'), 99),
#  (('a', 'n', 'o'), 98),
#  (('d', 'i', 'a'), 98),
#  (('z', 'a', '.'), 98),
#  (('m', 'o', 'r'), 98),
#  (('a', 'y', 'n'), 98),
#  (('a', 'k', 'e'), 98),
#  (('m', 'a', 't'), 98),
#  (('y', 'i', 'a'), 98),
#  (('r', 'l', 'i'), 97),
#  (('y', 'e', 'l'), 97),
#  (('z', 'a', 'y'), 97),
#  (('r', 'a', 'm'), 97),
#  (('v', 'a', 'l'), 96),
#  (('u', 'l', 'i'), 96),
#  (('y', 'r', 'i'), 96),
#  (('a', 's', 's'), 96),
#  (('i', 'd', 'a'), 96),
#  (('h', 'o', 'n'), 96),
#  (('.', 'k', 'r'), 96),
#  (('m', 'i', 'a'), 95),
#  (('e', 'n', 't'), 95),
#  (('v', 'i', 'e'), 95),
#  (('i', 'm', '.'), 95),
#  (('a', 'd', 'd'), 94),
#  (('c', 'h', 'i'), 94),
#  (('i', 'k', '.'), 94),
#  (('v', 'a', '.'), 93),
#  (('i', 'z', 'a'), 93),
#  (('n', 'e', 's'), 93),
#  (('j', 'o', 's'), 93),
#  (('k', 'a', 't'), 93),
#  (('.', 'e', 's'), 93),
#  (('y', 'n', 'e'), 93),
#  (('a', 'z', 'i'), 93),
#  (('c', 'a', 'm'), 92),
#  (('.', 'p', 'e'), 92),
#  (('e', 'a', 'h'), 92),
#  (('d', 'e', '.'), 92),
#  (('c', 'e', 'l'), 92),
#  (('.', 'n', 'y'), 92),
#  (('a', 'r', 's'), 92),
#  (('a', 'r', 'd'), 92),
#  (('l', 'e', 't'), 91),
#  (('.', 'w', 'i'), 91),
#  (('i', 'e', 'n'), 91),
#  (('a', 'm', 'y'), 91),
#  (('e', 'i', '.'), 91),
#  (('.', 'z', 'y'), 91),
#  (('d', 'a', 'm'), 91),
#  (('r', 'o', '.'), 91),
#  (('.', 'a', 'h'), 91),
#  (('i', 'u', 's'), 91),
#  (('o', 'v', 'a'), 90),
#  (('s', 'a', 'l'), 90),
#  (('n', 'i', 'c'), 90),
#  (('y', 'n', 'a'), 90),
#  (('n', 'd', 'a'), 90),
#  (('.', 'e', 'r'), 90),
#  (('d', 'a', 'y'), 90),
#  (('.', 'r', 'h'), 90),
#  (('v', 'i', 'o'), 89),
#  (('s', 'y', 'n'), 89),
#  (('n', 'a', 's'), 89),
#  (('m', 'a', 'h'), 89),
#  (('t', 'y', '.'), 88),
#  (('a', 'r', 'm'), 88),
#  (('a', 'h', 'm'), 88),
#  (('r', 'e', 't'), 87),
#  (('l', 'e', 'r'), 87),
#  (('i', 'n', 'i'), 87),
#  (('j', 'e', 'n'), 87),
#  (('i', 'n', 'd'), 87),
#  (('g', 'e', 'n'), 86),
#  (('d', 'r', 'a'), 86),
#  (('r', 'e', 's'), 86),
#  (('n', 'g', 'e'), 86),
#  (('o', 'n', 'e'), 86),
#  (('.', 'z', 'i'), 86),
#  (('.', 'y', 'u'), 86),
#  (('.', 'y', 'o'), 86),
#  (('a', 'b', 'r'), 85),
#  (('g', 'e', 'l'), 85),
#  (('.', 'b', 'l'), 85),
#  (('d', 'e', 'm'), 85),
#  (('e', 'y', 'l'), 85),
#  (('.', 'm', 'u'), 85),
#  (('e', 'r', 'y'), 84),
#  (('l', 'y', 's'), 84),
#  (('h', 'i', 'r'), 84),
#  (('b', 'e', 'n'), 84),
#  (('o', 'l', 'u'), 84),
#  (('u', 'w', 'a'), 84),
#  (('e', 'l', 'o'), 83),
#  (('z', 'e', 'l'), 83),
#  (('o', 'l', 'e'), 83),
#  (('s', 'a', 'r'), 83),
#  (('l', 'e', 'x'), 83),
#  (('e', 'v', 'i'), 83),
#  (('a', 'n', 'c'), 83),
#  (('a', 'a', 'r'), 83),
#  (('e', 's', 'h'), 83),
#  (('.', 'q', 'u'), 82),
#  (('j', 'a', 's'), 82),
#  (('m', 'i', 'k'), 82),
#  (('r', 'e', 'i'), 82),
#  (('a', 's', 'e'), 82),
#  (('y', 'l', 'y'), 82),
#  (('n', 'g', '.'), 82),
#  (('n', 't', 'a'), 82),
#  (('h', 'i', 'a'), 81),
#  (('l', 'i', 'z'), 81),
#  (('t', 'a', 'y'), 81),
#  (('m', 'a', 'e'), 81),
#  (('j', 'a', 'c'), 81),
#  (('a', 'l', 'o'), 81),
#  (('h', 'i', 'l'), 81),
#  (('n', 'i', 'k'), 81),
#  (('n', 'n', 'y'), 81),
#  (('s', 's', 'e'), 81),
#  (('r', 'l', 'y'), 80),
#  (('e', 'm', 'e'), 80),
#  (('.', 'e', 'd'), 80),
#  (('n', 'e', 'e'), 80),
#  (('r', 'r', 'a'), 80),
#  (('m', 'i', 'e'), 80),
#  (('n', 'y', 'a'), 80),
#  (('o', 'u', 'r'), 79),
#  (('.', 'f', 'r'), 79),
#  (('a', 'y', 'v'), 79),
#  (('e', 'e', 'l'), 79),
#  (('l', 'u', 'w'), 79),
#  (('i', 'v', 'i'), 78),
#  (('z', 'i', 'e'), 78),
#  (('c', 'o', 'l'), 78),
#  (('y', 'r', 'a'), 78),
#  (('l', 'i', 'o'), 78),
#  (('u', 'n', '.'), 78),
#  (('p', 'e', 'r'), 77),
#  (('m', 'a', 'c'), 77),
#  (('o', 'r', 'd'), 77),
#  (('a', 'c', 'h'), 77),
#  (('.', 'h', 'o'), 77),
#  (('n', 't', 'e'), 77),
#  (('y', 'a', 'r'), 77),
#  (('j', 'a', 'l'), 77),
#  (('.', 'd', 'r'), 77),
#  (('.', 'b', 'o'), 77),
#  (('y', 'c', 'e'), 77),
#  (('o', 's', '.'), 77),
#  (('s', 'a', 'b'), 76),
#  (('v', 'e', 'l'), 76),
#  (('a', 'b', 'i'), 76),
#  (('e', 'r', 's'), 76),
#  (('n', 'e', 'y'), 76),
#  (('i', 'c', 'h'), 76),
#  (('c', 'a', 's'), 76),
#  (('a', 'y', 'e'), 76),
#  (('u', 's', 't'), 76),
#  (('n', 'a', 'v'), 76),
#  (('d', 'i', 'n'), 76),
#  (('t', 'r', 'a'), 76),
#  (('e', 'e', 'm'), 76),
#  (('u', 'a', 'n'), 76),
#  (('r', 'y', 'l'), 75),
#  (('i', 'r', 'i'), 75),
#  (('m', 'i', 'y'), 75),
#  (('u', 'e', 'l'), 75),
#  (('k', 'e', 'i'), 75),
#  (('k', 'y', 'n'), 75),
#  (('t', 'i', 'a'), 75),
#  (('.', 'a', 'k'), 75),
#  (('o', 'm', 'i'), 74),
#  (('j', 'u', 'l'), 74),
#  (('s', 'i', 'e'), 74),
#  (('a', 't', 'i'), 74),
#  (('a', 'h', 'l'), 73),
#  (('.', 'j', 'i'), 73),
#  (('a', 't', 't'), 73),
#  (('z', 'a', 'n'), 73),
#  (('e', 'e', 'r'), 73),
#  (('m', 'm', 'a'), 72),
#  (('.', 'z', 'o'), 72),
#  (('r', 'e', 'a'), 72),
#  (('.', 'a', 't'), 72),
#  (('y', 'l', 'o'), 72),
#  (('t', 'h', 'i'), 72),
#  (('k', 'e', 'y'), 72),
#  (('n', 'a', 'r'), 72),
#  (('r', 'r', 'e'), 72),
#  (('.', 'f', 'i'), 71),
#  (('.', 's', 'y'), 71),
#  (('c', 'i', 'a'), 71),
#  (('d', 'e', 's'), 71),
#  (('o', 'h', 'a'), 71),
#  (('s', 'a', 'i'), 71),
#  (('t', 'a', 'r'), 71),
#  (('z', 'i', 'a'), 71),
#  (('i', 'n', 'o'), 71),
#  (('e', 'd', '.'), 71),
#  (('o', 'l', 'l'), 70),
#  (('q', 'u', 'e'), 70),
#  (('i', 'v', 'a'), 70),
#  (('a', 'r', 'c'), 70),
#  (('k', 'a', 'n'), 70),
#  (('o', 'l', 'i'), 69),
#  (('b', 'r', 'o'), 69),
#  (('l', 'u', 'c'), 69),
#  (('k', 'e', 'r'), 69),
#  (('d', 'a', 'i'), 69),
#  (('r', 'e', 'm'), 69),
#  (('a', 'd', 'r'), 69),
#  (('c', 'h', 'r'), 69),
#  (('d', 'a', 'v'), 69),
#  (('z', 'a', 'i'), 69),
#  (('l', 'a', 'm'), 69),
#  (('y', 'a', 's'), 69),
#  (('m', 'e', 'e'), 69),
#  (('i', 's', 'o'), 68),
#  (('.', 'c', 'l'), 68),
#  (('e', 'n', 'z'), 68),
#  (('r', 'y', 's'), 68),
#  (('.', 'w', 'a'), 68),
#  (('s', 'i', 'r'), 68),
#  (('i', 'h', 'a'), 68),
#  (('o', 'u', 's'), 68),
#  (('s', 'e', 'r'), 67),
#  (('q', 'u', 'i'), 67),
#  (('.', 'v', 'e'), 67),
#  (('m', 'i', 'c'), 67),
#  (('.', 'c', 'r'), 67),
#  (('.', 'h', 'u'), 67),
#  (('.', 'i', 'l'), 67),
#  (('s', 't', 'y'), 67),
#  (('a', 'i', 'z'), 67),
#  (('l', 'a', 'k'), 66),
#  (('a', 't', 'e'), 66),
#  (('i', 'c', '.'), 66),
#  (('z', 'a', 'l'), 66),
#  (('i', 'd', '.'), 66),
#  (('o', 'm', 'a'), 66),
#  (('h', 'a', 'w'), 66),
#  (('a', 'u', 'n'), 66),
#  (('.', 'c', 'e'), 65),
#  (('i', 'l', 'o'), 65),
#  (('a', 'b', 'd'), 65),
#  (('d', 'o', '.'), 65),
#  (('d', 'i', 'l'), 64),
#  (('e', 'r', 'o'), 64),
#  (('k', 'r', 'i'), 64),
#  (('y', 's', '.'), 64),
#  (('o', 'r', 'r'), 64),
#  (('t', 'e', 'l'), 63),
#  (('i', 's', 'l'), 63),
#  (('n', 's', 'l'), 63),
#  (('i', 'c', 'e'), 63),
#  (('m', 'y', 'a'), 63),
#  (('o', 's', 'a'), 63),
#  (('c', 'a', '.'), 63),
#  (('n', 'e', 't'), 63),
#  (('k', 'e', 'e'), 63),
#  (('k', 'o', 'l'), 63),
#  (('d', 'e', 'e'), 63),
#  (('r', 'i', 'l'), 62),
#  (('o', 'r', 'y'), 62),
#  (('k', 'o', 'r'), 62),
#  (('j', 'a', 'k'), 62),
#  (('h', 'a', 's'), 62),
#  (('h', 'a', 'a'), 62),
#  (('i', 'm', 'i'), 62),
#  (('p', 'h', 'i'), 61),
#  (('b', 'e', 't'), 61),
#  (('u', 'n', 'a'), 61),
#  (('a', 'r', 'k'), 61),
#  (('e', 's', 'l'), 61),
#  (('a', 'y', 't'), 61),
#  (('i', 'v', 'e'), 61),
#  (('j', 'e', 's'), 61),
#  (('e', 'n', 's'), 61),
#  (('e', 'n', 'l'), 61),
#  (('k', 'a', 'e'), 61),
#  (('.', 'w', 'e'), 61),
#  (('.', 'y', 'e'), 61),
#  (('a', 'z', 'e'), 60),
#  (('c', 'l', 'a'), 60),
#  (('m', 'e', 'n'), 60),
#  (('l', 'e', 'o'), 60),
#  (('.', 'e', 'n'), 60),
#  (('n', 'd', 'i'), 60),
#  (('r', 'i', 'k'), 60),
#  (('.', 'i', 'n'), 60),
#  (('t', 'l', 'e'), 60),
#  (('s', 'i', 'n'), 60),
#  (('t', 'i', '.'), 60),
#  (('g', 'e', 'r'), 60),
#  (('a', 's', 'a'), 60),
#  (('a', 'c', 'k'), 59),
#  (('m', 'b', 'e'), 59),
#  (('c', 'i', 'e'), 59),
#  (('.', 'i', 'z'), 59),
#  (('a', 'd', 'o'), 59),
#  (('d', 'o', 'r'), 59),
#  (('y', 's', 'e'), 59),
#  (('s', 'l', 'y'), 59),
#  (('z', 'l', 'e'), 59),
#  (('i', 'j', 'a'), 59),
#  (('n', 'e', 'r'), 59),
#  (('w', 'a', '.'), 59),
#  (('a', 'v', 'o'), 59),
#  (('i', 'i', '.'), 59),
#  (('k', 'o', '.'), 59),
#  (('l', 'l', 'o'), 58),
#  (('i', 'n', 's'), 58),
#  (('n', 'i', 't'), 58),
#  (('e', 'n', 'c'), 58),
#  (('y', 's', 'o'), 58),
#  (('g', 'h', 'a'), 58),
#  (('a', 'y', 'c'), 58),
#  (('i', 'z', 'e'), 58),
#  (('v', 'i', 'k'), 58),
#  (('k', 'i', '.'), 58),
#  (('t', 'o', '.'), 58),
#  (('e', 's', 'i'), 57),
#  (('h', 'i', 'n'), 57),
#  (('e', 'i', 'a'), 57),
#  (('i', 'c', 'a'), 57),
#  (('r', 'o', 'm'), 57),
#  (('r', 'm', 'a'), 57),
#  (('h', 'y', 'a'), 57),
#  (('a', 'd', 'y'), 57),
#  (('a', 'h', 'n'), 57),
#  (('.', 'x', 'a'), 57),
#  (('r', 'd', '.'), 57),
#  (('w', 'i', 'l'), 56),
#  (('e', 'd', 'e'), 56),
#  (('a', 'c', 'i'), 56),
#  (('u', 'r', 'a'), 56),
#  (('h', 'l', 'a'), 56),
#  (('j', 'a', 'z'), 56),
#  (('s', 's', '.'), 56),
#  (('a', 't', '.'), 56),
#  (('c', 'a', 'i'), 56),
#  (('d', 'e', 'v'), 56),
#  (('v', 'a', 'r'), 56),
#  (('q', 'u', 'a'), 56),
#  (('.', 's', 'k'), 55),
#  (('b', 'y', '.'), 55),
#  (('k', 'i', 'a'), 55),
#  (('w', 'i', 'n'), 55),
#  (('t', 'a', 'v'), 55),
#  (('j', 'o', 'h'), 55),
#  (('l', 'a', 's'), 55),
#  (('e', 'd', 'a'), 55),
#  (('f', 'a', 'r'), 55),
#  (('z', 'e', 'n'), 55),
#  (('j', 'a', '.'), 55),
#  (('.', 'a', 'e'), 55),
#  (('.', 'h', 'i'), 55),
#  (('i', 't', '.'), 55),
#  (('a', 'y', 'm'), 55),
#  (('t', 'a', 'i'), 55),
#  (('i', 'a', 's'), 55),
#  (('l', 'i', 'v'), 54),
#  (('f', 'i', 'n'), 54),
#  (('j', 'o', 'r'), 54),
#  (('m', 'y', '.'), 54),
#  (('r', 'n', 'e'), 54),
#  (('b', 'l', 'a'), 54),
#  (('i', 'a', 'r'), 54),
#  (('a', 'l', 'd'), 54),
#  (('a', 'm', 'r'), 54),
#  (('f', 'r', 'a'), 54),
#  (('n', 't', 'o'), 54),
#  (('s', 'i', '.'), 54),
#  (('.', 'e', 'i'), 54),
#  (('n', 's', 'h'), 54),
#  (('y', 'r', 'e'), 54),
#  (('n', 'd', 'y'), 53),
#  (('h', 'a', 'v'), 53),
#  (('k', 'a', 'h'), 53),
#  (('t', 't', 'a'), 53),
#  (('s', 'o', 'l'), 53),
#  (('r', 'i', 'g'), 53),
#  (('a', 'e', 'd'), 53),
#  (('n', 'o', 'v'), 52),
#  (('c', 'k', 'e'), 52),
#  (('e', 'g', 'a'), 52),
#  (('i', 'a', 'm'), 52),
#  (('.', 'p', 'h'), 52),
#  (('e', 's', 'a'), 52),
#  (('.', 'e', 'z'), 52),
#  (('u', 'e', '.'), 52),
#  (('h', 'y', 'l'), 52),
#  (('a', 'k', 'y'), 52),
#  (('a', 'w', 'n'), 52),
#  (('a', 'j', 'a'), 52),
#  (('i', 'k', 'o'), 52),
#  (('d', 'd', 'i'), 51),
#  (('g', 'a', 'r'), 51),
#  (('n', 'd', 'o'), 51),
#  (('e', 'i', 'r'), 51),
#  (('s', 'e', 'y'), 51),
#  (('t', 'i', 'e'), 51),
#  (('a', 'm', 'b'), 51),
#  (('p', 'r', 'i'), 51),
#  (('e', 'r', 't'), 51),
#  (('r', 'i', 'd'), 51),
#  (('k', 'i', 'e'), 51),
#  (('j', 'a', 'e'), 51),
#  (('i', 't', 't'), 51),
#  (('h', 'i', 't'), 51),
#  (('a', 'i', 'm'), 51),
#  (('w', 'n', '.'), 51),
#  (('r', 'a', 'd'), 51),
#  (('a', 'y', 'o'), 51),
#  (('e', 'a', 'l'), 51),
#  (('g', 'i', 'a'), 50),
#  (('e', 'p', 'h'), 50),
#  (('a', 'i', 't'), 50),
#  (('i', 'x', '.'), 50),
#  (('z', 'a', 'h'), 50),
#  (('c', 'a', 'y'), 50),
#  (('a', 'n', 'u'), 50),
#  (('e', 'k', '.'), 50),
#  (('r', 'i', 'u'), 50),
#  (('a', 'u', 'd'), 49),
#  (('.', 'i', 'v'), 49),
#  (('.', 'i', 'r'), 49),
#  (('e', 's', 'e'), 49),
#  (('m', 'y', 'l'), 49),
#  (('.', 'f', 'e'), 49),
#  (('i', 'd', 'y'), 49),
#  (('y', 'a', 'l'), 49),
#  (('r', 'e', 'd'), 49),
#  (('h', 'a', 'e'), 49),
#  (('g', 'r', 'e'), 49),
#  (('k', 'y', 'r'), 49),
#  (('b', 'a', 'r'), 49),
#  (('a', 'n', 'v'), 49),
#  (('e', 'r', 'm'), 49),
#  (('m', 'e', 's'), 49),
#  (('j', 'a', 'r'), 49),
#  (('a', 'r', 'v'), 49),
#  (('n', 't', 'i'), 48),
#  (('u', 'r', 'e'), 48),
#  (('k', 'e', '.'), 48),
#  (('.', 'm', 'c'), 48),
#  (('a', 'k', 'o'), 48),
#  (('w', 'y', 'n'), 48),
#  (('u', 'l', 'a'), 48),
#  (('m', 'e', 'i'), 48),
#  (('n', 'a', 'e'), 48),
#  (('o', 'm', 'e'), 48),
#  (('m', 'a', 's'), 48),
#  (('r', 'a', 's'), 48),
#  (('j', 'a', 'v'), 48),
#  (('u', 'i', 'n'), 47),
#  (('o', 'e', 'l'), 47),
#  (('.', 'z', 'u'), 47),
#  (('w', 'e', 'n'), 47),
#  (('n', 'o', 'n'), 47),
#  (('e', 'd', 'i'), 47),
#  (('i', 'n', 'c'), 47),
#  (('a', 'a', 'd'), 47),
#  (('e', 'i', 's'), 47),
#  (('c', 'e', 'n'), 47),
#  (('.', 'o', 'r'), 47),
#  (('z', 'a', 'm'), 47),
#  (('z', 'a', 'k'), 47),
#  (('i', 'r', 'o'), 47),
#  (('a', 'a', 'l'), 46),
#  (('n', 'z', 'i'), 46),
#  (('e', 'e', 's'), 46),
#  (('l', 'a', 'u'), 46),
#  (('o', 'n', 'd'), 46),
#  (('n', 'y', 'l'), 46),
#  (('s', 'e', 'a'), 46),
#  (('e', 'm', 'o'), 46),
#  (('.', 'c', 'y'), 46),
#  (('s', 'i', 'm'), 46),
#  (('m', 'i', 's'), 46),
#  (('a', 'v', 'y'), 46),
#  (('b', 'a', '.'), 46),
#  (('u', 'm', 'a'), 46),
#  (('k', 'h', 'y'), 46),
#  (('r', 'u', 's'), 46),
#  (('a', 'h', 'e'), 46),
#  (('r', 's', 'h'), 46),
#  (('y', 'a', 'a'), 46),
#  (('p', 'a', 'r'), 45),
#  (('h', 'e', 'a'), 45),
#  (('f', 'e', 'r'), 45),
#  (('y', 's', 'i'), 45),
#  (('y', 'd', 'a'), 45),
#  (('m', 'a', 'x'), 45),
#  (('.', 'g', 'u'), 45),
#  (('n', 'v', 'i'), 45),
#  (('z', 'e', '.'), 45),
#  (('t', 'a', 'm'), 45),
#  (('a', 't', 'o'), 45),
#  (('j', 'o', 'n'), 45),
#  (('a', 'j', '.'), 45),
#  (('a', 'v', '.'), 45),
#  (('r', 'l', 'o'), 44),
#  (('s', 'k', 'y'), 44),
#  (('n', 't', 'h'), 44),
#  (('i', 't', 'y'), 44),
#  (('j', 'a', 'd'), 44),
#  (('i', 'n', 'l'), 44),
#  (('k', 'i', 'm'), 44),
#  (('o', 's', 'i'), 44),
#  (('g', 'e', '.'), 44),
#  (('f', 'r', 'e'), 44),
#  (('k', 'l', 'e'), 44),
#  (('i', 't', 'z'), 44),
#  (('s', 'a', 'h'), 44),
#  (('.', 'c', 'i'), 44),
#  (('e', 'n', 'o'), 44),
#  (('d', 'e', 'a'), 44),
#  (('a', 'y', 'r'), 44),
#  (('e', 'v', 'o'), 44),
#  (('c', 'o', 'n'), 44),
#  (('s', 'h', 'o'), 44),
#  (('h', 'm', 'a'), 44),
#  (('e', 'c', 'k'), 44),
#  (('j', 'a', 'x'), 44),
#  (('b', 'a', 's'), 44),
#  (('d', 'h', 'a'), 44),
#  (('o', 'n', 'y'), 43),
#  (('s', 'i', 'd'), 43),
#  (('y', 'e', '.'), 43),
#  (('y', 's', 't'), 43),
#  (('l', 'o', 'u'), 43),
#  (('e', 'n', 'y'), 43),
#  (('y', 'v', 'i'), 43),
#  (('s', 'm', 'a'), 43),
#  (('u', 'h', 'a'), 43),
#  (('v', 'e', 'e'), 43),
#  (('m', 'i', 't'), 43),
#  (('t', 'h', 'o'), 43),
#  (('y', 'm', 'a'), 43),
#  (('d', 'i', 's'), 42),
#  ...]

# %%
len(t)
# Out:
# 6037

# %%
chars = sorted(set(''.join(words)))

# %%
stoi = {s:i+1 for i,s in enumerate(chars)}
stoi['.'] = 0
itos = {i:s for s,i in stoi.items()}

# %%
import torch

tensor = torch.zeros((27,27,27),dtype=torch.int32)

# %%
for w in words:
    chs = ['.'] + list(w) + ['.']
    for ch1, ch2, ch3 in zip(chs, chs[1:], chs[2:]):
        ix1 = stoi[ch1]
        ix2 = stoi[ch2]
        ix3 = stoi[ch3]

        tensor[ix1,ix2,ix3] += 1

# %%
tensor = tensor.float()
tensor += 0.1 # smoothing

tensor = tensor / tensor.sum(axis=2,keepdim=True)

# %%
g = torch.Generator().manual_seed(2147483647)
c = 0

for i in range(10):
    ix1 = 0
    ix2 = 0
    out = []
    temperature = 0.6

    while True:
        p = tensor[ix1,ix2] ** (1.0/temperature)
        ix3 = torch.multinomial(p,num_samples=1,replacement=True,generator=g).item()
        if ix3 == 0:
            break
        out.append(itos[ix3])
        ix1, ix2 = ix2, ix3
        
    print(''.join(out))
# Out:
# juniden
# pracar
# pariah
# olin
# fair
# lailia
# sarie
# umanna
# uria
# len

# %%
# calculating loss

log_likelihood = 0
n = 0

for w in words:
#for w in ['kiran']:

    chs = ['.'] + list(w) + ['.']
    for ch1, ch2, ch3 in zip(chs, chs[1:], chs[2:]):
        ix1 = stoi[ch1]
        ix2 = stoi[ch2]
        ix3 = stoi[ch3]

        prob = tensor[ix1,ix2,ix3]
        log_prob = torch.log(prob)
        log_likelihood += log_prob
        n += 1


print(f'{log_likelihood = }')
nll = -log_likelihood
print(f'{nll = }')
print(f'{nll/n}')
# Out:
# log_likelihood = tensor(-405251.6875)
# nll = tensor(405251.6875)
# 2.0664193630218506

# %%
# Neural network approach
device = 'cuda' if torch.cuda.is_available() else 'cpu'


xs,ys = [],[]

for w in words:

    chs = ['.'] + list(w) + ['.']
    for ch1, ch2, ch3 in zip(chs, chs[1:], chs[2:]):
        ix1 = stoi[ch1]
        ix2 = stoi[ch2]
        ix3 = stoi[ch3]

        xs.append([ix1,ix2])
        ys.append(ix3)


xs = torch.tensor(xs, device=device)
ys = torch.tensor(ys, device=device)
num = xs.shape[0]




g = torch.Generator(device=device).manual_seed(2147483647)
W = torch.randn((54, 27), generator=g, requires_grad=True, device=device)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'


xs = torch.tensor(xs, device=device)
ys = torch.tensor(ys, device=device)
num = xs.shape[0]

xenc = F.one_hot(xs, num_classes=27).float().to(device)  # shape: [num, 2, 27]
xenc = xenc.view(-1, 2 * 27)  # shape: [num, 54]

g = torch.Generator(device=device).manual_seed(2147483647)
W = torch.randn((54, 27), generator=g, requires_grad=True, device=device)
# Out:
# /tmp/ipykernel_79189/786169802.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   xs = torch.tensor(xs, device=device)
# /tmp/ipykernel_79189/786169802.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   ys = torch.tensor(ys, device=device)

# %%
epoch = 0
for k in range(1000):
    # Forward pass
    logits = xenc @ W
    loss = F.cross_entropy(logits, ys)  
    print(f'{loss.item()=}, {epoch=}')
    # Backward pass
    W.grad = None
    loss.backward()


    W.data += -1.0 * W.grad  

   
    epoch += 1
# Out:
# loss.item()=2.2432398796081543, epoch=0
# loss.item()=2.243238925933838, epoch=1
# loss.item()=2.243238687515259, epoch=2
# loss.item()=2.243237257003784, epoch=3
# loss.item()=2.243237257003784, epoch=4
# loss.item()=2.243236541748047, epoch=5
# loss.item()=2.2432363033294678, epoch=6
# loss.item()=2.2432353496551514, epoch=7
# loss.item()=2.243234157562256, epoch=8
# loss.item()=2.2432336807250977, epoch=9
# loss.item()=2.2432334423065186, epoch=10
# loss.item()=2.243232488632202, epoch=11
# loss.item()=2.2432327270507812, epoch=12
# loss.item()=2.243232250213623, epoch=13
# loss.item()=2.243232011795044, epoch=14
# loss.item()=2.243231773376465, epoch=15
# loss.item()=2.2432310581207275, epoch=16
# loss.item()=2.2432310581207275, epoch=17
# loss.item()=2.2432303428649902, epoch=18
# loss.item()=2.243229866027832, epoch=19
# loss.item()=2.2432291507720947, epoch=20
# loss.item()=2.2432284355163574, epoch=21
# loss.item()=2.2432284355163574, epoch=22
# loss.item()=2.24322772026062, epoch=23
# loss.item()=2.2432267665863037, epoch=24
# loss.item()=2.2432260513305664, epoch=25
# loss.item()=2.243225574493408, epoch=26
# loss.item()=2.243225574493408, epoch=27
# loss.item()=2.243224859237671, epoch=28
# loss.item()=2.2432241439819336, epoch=29
# loss.item()=2.2432236671447754, epoch=30
# loss.item()=2.24322247505188, epoch=31
# loss.item()=2.243222236633301, epoch=32
# loss.item()=2.2432217597961426, epoch=33
# loss.item()=2.2432217597961426, epoch=34
# loss.item()=2.243220806121826, epoch=35
# loss.item()=2.243220090866089, epoch=36
# loss.item()=2.2432198524475098, epoch=37
# loss.item()=2.2432196140289307, epoch=38
# loss.item()=2.2432188987731934, epoch=39
# loss.item()=2.243218421936035, epoch=40
# loss.item()=2.243217945098877, epoch=41
# loss.item()=2.2432174682617188, epoch=42
# loss.item()=2.243217706680298, epoch=43
# loss.item()=2.2432165145874023, epoch=44
# loss.item()=2.243216037750244, epoch=45
# loss.item()=2.243215799331665, epoch=46
# loss.item()=2.2432150840759277, epoch=47
# loss.item()=2.2432146072387695, epoch=48
# loss.item()=2.2432146072387695, epoch=49
# loss.item()=2.2432138919830322, epoch=50
# loss.item()=2.243213653564453, epoch=51
# loss.item()=2.243213653564453, epoch=52
# loss.item()=2.243213176727295, epoch=53
# loss.item()=2.2432124614715576, epoch=54
# loss.item()=2.2432122230529785, epoch=55
# loss.item()=2.2432117462158203, epoch=56
# loss.item()=2.2432103157043457, epoch=57
# loss.item()=2.2432103157043457, epoch=58
# loss.item()=2.2432103157043457, epoch=59
# loss.item()=2.2432098388671875, epoch=60
# loss.item()=2.2432093620300293, epoch=61
# loss.item()=2.243208885192871, epoch=62
# loss.item()=2.243208885192871, epoch=63
# loss.item()=2.243208408355713, epoch=64
# loss.item()=2.2432074546813965, epoch=65
# loss.item()=2.2432069778442383, epoch=66
# loss.item()=2.243206739425659, epoch=67
# loss.item()=2.243206024169922, epoch=68
# loss.item()=2.2432055473327637, epoch=69
# loss.item()=2.2432055473327637, epoch=70
# loss.item()=2.243204355239868, epoch=71
# loss.item()=2.243204116821289, epoch=72
# loss.item()=2.2432034015655518, epoch=73
# loss.item()=2.2432029247283936, epoch=74
# loss.item()=2.2432026863098145, epoch=75
# loss.item()=2.2432022094726562, epoch=76
# loss.item()=2.243201732635498, epoch=77
# loss.item()=2.243201494216919, epoch=78
# loss.item()=2.24320125579834, epoch=79
# loss.item()=2.2431998252868652, epoch=80
# loss.item()=2.2431998252868652, epoch=81
# loss.item()=2.243199348449707, epoch=82
# loss.item()=2.2431983947753906, epoch=83
# loss.item()=2.2431979179382324, epoch=84
# loss.item()=2.243197441101074, epoch=85
# loss.item()=2.243196725845337, epoch=86
# loss.item()=2.2431960105895996, epoch=87
# loss.item()=2.2431962490081787, epoch=88
# loss.item()=2.2431952953338623, epoch=89
# loss.item()=2.243194580078125, epoch=90
# loss.item()=2.243194580078125, epoch=91
# loss.item()=2.2431938648223877, epoch=92
# loss.item()=2.2431933879852295, epoch=93
# loss.item()=2.2431931495666504, epoch=94
# loss.item()=2.243192672729492, epoch=95
# loss.item()=2.243191957473755, epoch=96
# loss.item()=2.2431910037994385, epoch=97
# loss.item()=2.243190288543701, epoch=98
# loss.item()=2.243190050125122, epoch=99
# loss.item()=2.2431893348693848, epoch=100
# loss.item()=2.2431890964508057, epoch=101
# loss.item()=2.2431881427764893, epoch=102
# loss.item()=2.24318790435791, epoch=103
# loss.item()=2.243187189102173, epoch=104
# loss.item()=2.243187427520752, epoch=105
# loss.item()=2.2431867122650146, epoch=106
# loss.item()=2.2431862354278564, epoch=107
# loss.item()=2.24318528175354, epoch=108
# loss.item()=2.2431838512420654, epoch=109
# loss.item()=2.2431833744049072, epoch=110
# loss.item()=2.243182897567749, epoch=111
# loss.item()=2.24318265914917, epoch=112
# loss.item()=2.24318265914917, epoch=113
# loss.item()=2.243180751800537, epoch=114
# loss.item()=2.243180274963379, epoch=115
# loss.item()=2.243180513381958, epoch=116
# loss.item()=2.2431797981262207, epoch=117
# loss.item()=2.2431790828704834, epoch=118
# loss.item()=2.243178606033325, epoch=119
# loss.item()=2.243177652359009, epoch=120
# loss.item()=2.2431774139404297, epoch=121
# loss.item()=2.243177652359009, epoch=122
# loss.item()=2.243177890777588, epoch=123
# loss.item()=2.2431771755218506, epoch=124
# loss.item()=2.243176221847534, epoch=125
# loss.item()=2.243175983428955, epoch=126
# loss.item()=2.243175745010376, epoch=127
# loss.item()=2.2431750297546387, epoch=128
# loss.item()=2.2431750297546387, epoch=129
# loss.item()=2.243173837661743, epoch=130
# loss.item()=2.243173122406006, epoch=131
# loss.item()=2.2431721687316895, epoch=132
# loss.item()=2.2431716918945312, epoch=133
# loss.item()=2.243170976638794, epoch=134
# loss.item()=2.243170738220215, epoch=135
# loss.item()=2.2431704998016357, epoch=136
# loss.item()=2.2431695461273193, epoch=137
# loss.item()=2.243168592453003, epoch=138
# loss.item()=2.243168354034424, epoch=139
# loss.item()=2.2431676387786865, epoch=140
# loss.item()=2.2431676387786865, epoch=141
# loss.item()=2.2431671619415283, epoch=142
# loss.item()=2.24316668510437, epoch=143
# loss.item()=2.243166923522949, epoch=144
# loss.item()=2.243166446685791, epoch=145
# loss.item()=2.243166446685791, epoch=146
# loss.item()=2.2431650161743164, epoch=147
# loss.item()=2.243164300918579, epoch=148
# loss.item()=2.243163824081421, epoch=149
# loss.item()=2.2431623935699463, epoch=150
# loss.item()=2.243161916732788, epoch=151
# loss.item()=2.24316143989563, epoch=152
# loss.item()=2.243161201477051, epoch=153
# loss.item()=2.2431609630584717, epoch=154
# loss.item()=2.2431607246398926, epoch=155
# loss.item()=2.243159770965576, epoch=156
# loss.item()=2.2431588172912598, epoch=157
# loss.item()=2.2431585788726807, epoch=158
# loss.item()=2.243157386779785, epoch=159
# loss.item()=2.243157148361206, epoch=160
# loss.item()=2.2431564331054688, epoch=161
# loss.item()=2.2431559562683105, epoch=162
# loss.item()=2.243155002593994, epoch=163
# loss.item()=2.2431540489196777, epoch=164
# loss.item()=2.2431535720825195, epoch=165
# loss.item()=2.2431528568267822, epoch=166
# loss.item()=2.243152618408203, epoch=167
# loss.item()=2.243151903152466, epoch=168
# loss.item()=2.2431516647338867, epoch=169
# loss.item()=2.2431511878967285, epoch=170
# loss.item()=2.243150472640991, epoch=171
# loss.item()=2.243150234222412, epoch=172
# loss.item()=2.2431488037109375, epoch=173
# loss.item()=2.2431492805480957, epoch=174
# loss.item()=2.2431488037109375, epoch=175
# loss.item()=2.2431480884552, epoch=176
# loss.item()=2.2431480884552, epoch=177
# loss.item()=2.243147850036621, epoch=178
# loss.item()=2.243147373199463, epoch=179
# loss.item()=2.2431468963623047, epoch=180
# loss.item()=2.2431461811065674, epoch=181
# loss.item()=2.24314546585083, epoch=182
# loss.item()=2.243145227432251, epoch=183
# loss.item()=2.243144989013672, epoch=184
# loss.item()=2.2431440353393555, epoch=185
# loss.item()=2.243143081665039, epoch=186
# loss.item()=2.243143081665039, epoch=187
# loss.item()=2.2431423664093018, epoch=188
# loss.item()=2.2431418895721436, epoch=189
# loss.item()=2.243140935897827, epoch=190
# loss.item()=2.24314022064209, epoch=191
# loss.item()=2.2431395053863525, epoch=192
# loss.item()=2.2431392669677734, epoch=193
# loss.item()=2.2431387901306152, epoch=194
# loss.item()=2.243138551712036, epoch=195
# loss.item()=2.243138313293457, epoch=196
# loss.item()=2.243137836456299, epoch=197
# loss.item()=2.2431375980377197, epoch=198
# loss.item()=2.2431373596191406, epoch=199
# loss.item()=2.2431366443634033, epoch=200
# loss.item()=2.243135929107666, epoch=201
# loss.item()=2.243135690689087, epoch=202
# loss.item()=2.243135929107666, epoch=203
# loss.item()=2.2431349754333496, epoch=204
# loss.item()=2.2431344985961914, epoch=205
# loss.item()=2.2431342601776123, epoch=206
# loss.item()=2.2431342601776123, epoch=207
# loss.item()=2.243133544921875, epoch=208
# loss.item()=2.243133544921875, epoch=209
# loss.item()=2.2431328296661377, epoch=210
# loss.item()=2.2431323528289795, epoch=211
# loss.item()=2.243130922317505, epoch=212
# loss.item()=2.2431299686431885, epoch=213
# loss.item()=2.2431297302246094, epoch=214
# loss.item()=2.243129253387451, epoch=215
# loss.item()=2.243128538131714, epoch=216
# loss.item()=2.2431280612945557, epoch=217
# loss.item()=2.2431278228759766, epoch=218
# loss.item()=2.2431275844573975, epoch=219
# loss.item()=2.2431275844573975, epoch=220
# loss.item()=2.2431271076202393, epoch=221
# loss.item()=2.243126153945923, epoch=222
# loss.item()=2.2431247234344482, epoch=223
# loss.item()=2.243124008178711, epoch=224
# loss.item()=2.2431235313415527, epoch=225
# loss.item()=2.2431228160858154, epoch=226
# loss.item()=2.243122100830078, epoch=227
# loss.item()=2.243121862411499, epoch=228
# loss.item()=2.243121385574341, epoch=229
# loss.item()=2.243122100830078, epoch=230
# loss.item()=2.243121385574341, epoch=231
# loss.item()=2.243121385574341, epoch=232
# loss.item()=2.2431209087371826, epoch=233
# loss.item()=2.2431201934814453, epoch=234
# loss.item()=2.24311900138855, epoch=235
# loss.item()=2.24311900138855, epoch=236
# loss.item()=2.2431185245513916, epoch=237
# loss.item()=2.2431187629699707, epoch=238
# loss.item()=2.2431180477142334, epoch=239
# loss.item()=2.2431180477142334, epoch=240
# loss.item()=2.2431180477142334, epoch=241
# loss.item()=2.243117570877075, epoch=242
# loss.item()=2.243117094039917, epoch=243
# loss.item()=2.2431163787841797, epoch=244
# loss.item()=2.243115186691284, epoch=245
# loss.item()=2.243112564086914, epoch=246
# loss.item()=2.243112325668335, epoch=247
# loss.item()=2.2431118488311768, epoch=248
# loss.item()=2.2431116104125977, epoch=249
# loss.item()=2.2431106567382812, epoch=250
# loss.item()=2.243110179901123, epoch=251
# loss.item()=2.2431094646453857, epoch=252
# loss.item()=2.2431087493896484, epoch=253
# loss.item()=2.2431082725524902, epoch=254
# loss.item()=2.243107557296753, epoch=255
# loss.item()=2.243107318878174, epoch=256
# loss.item()=2.2431066036224365, epoch=257
# loss.item()=2.2431061267852783, epoch=258
# loss.item()=2.2431046962738037, epoch=259
# loss.item()=2.2431046962738037, epoch=260
# loss.item()=2.2431042194366455, epoch=261
# loss.item()=2.2431039810180664, epoch=262
# loss.item()=2.2431037425994873, epoch=263
# loss.item()=2.24310302734375, epoch=264
# loss.item()=2.243102550506592, epoch=265
# loss.item()=2.2431023120880127, epoch=266
# loss.item()=2.2431015968322754, epoch=267
# loss.item()=2.24310040473938, epoch=268
# loss.item()=2.243100166320801, epoch=269
# loss.item()=2.2430999279022217, epoch=270
# loss.item()=2.2430992126464844, epoch=271
# loss.item()=2.2430989742279053, epoch=272
# loss.item()=2.243098735809326, epoch=273
# loss.item()=2.243098258972168, epoch=274
# loss.item()=2.2430968284606934, epoch=275
# loss.item()=2.2430968284606934, epoch=276
# loss.item()=2.2430973052978516, epoch=277
# loss.item()=2.2430968284606934, epoch=278
# loss.item()=2.243096351623535, epoch=279
# loss.item()=2.243095874786377, epoch=280
# loss.item()=2.2430953979492188, epoch=281
# loss.item()=2.2430944442749023, epoch=282
# loss.item()=2.243093252182007, epoch=283
# loss.item()=2.2430927753448486, epoch=284
# loss.item()=2.2430922985076904, epoch=285
# loss.item()=2.2430920600891113, epoch=286
# loss.item()=2.243091583251953, epoch=287
# loss.item()=2.243091344833374, epoch=288
# loss.item()=2.243091344833374, epoch=289
# loss.item()=2.2430906295776367, epoch=290
# loss.item()=2.2430896759033203, epoch=291
# loss.item()=2.243088722229004, epoch=292
# loss.item()=2.243088722229004, epoch=293
# loss.item()=2.2430882453918457, epoch=294
# loss.item()=2.2430877685546875, epoch=295
# loss.item()=2.2430872917175293, epoch=296
# loss.item()=2.243086814880371, epoch=297
# loss.item()=2.243086338043213, epoch=298
# loss.item()=2.243086338043213, epoch=299
# loss.item()=2.2430856227874756, epoch=300
# loss.item()=2.2430853843688965, epoch=301
# loss.item()=2.2430849075317383, epoch=302
# loss.item()=2.2430834770202637, epoch=303
# loss.item()=2.2430837154388428, epoch=304
# loss.item()=2.2430832386016846, epoch=305
# loss.item()=2.2430832386016846, epoch=306
# loss.item()=2.243082046508789, epoch=307
# loss.item()=2.243081569671631, epoch=308
# loss.item()=2.2430806159973145, epoch=309
# loss.item()=2.2430801391601562, epoch=310
# loss.item()=2.24307918548584, epoch=311
# loss.item()=2.24307918548584, epoch=312
# loss.item()=2.24307918548584, epoch=313
# loss.item()=2.2430787086486816, epoch=314
# loss.item()=2.2430784702301025, epoch=315
# loss.item()=2.2430787086486816, epoch=316
# loss.item()=2.2430784702301025, epoch=317
# loss.item()=2.243077278137207, epoch=318
# loss.item()=2.243077278137207, epoch=319
# loss.item()=2.2430765628814697, epoch=320
# loss.item()=2.2430756092071533, epoch=321
# loss.item()=2.243074655532837, epoch=322
# loss.item()=2.243075370788574, epoch=323
# loss.item()=2.2430756092071533, epoch=324
# loss.item()=2.243074655532837, epoch=325
# loss.item()=2.2430739402770996, epoch=326
# loss.item()=2.243072986602783, epoch=327
# loss.item()=2.243072986602783, epoch=328
# loss.item()=2.243072748184204, epoch=329
# loss.item()=2.243072271347046, epoch=330
# loss.item()=2.2430713176727295, epoch=331
# loss.item()=2.243070363998413, epoch=332
# loss.item()=2.243070363998413, epoch=333
# loss.item()=2.243069887161255, epoch=334
# loss.item()=2.2430694103240967, epoch=335
# loss.item()=2.2430689334869385, epoch=336
# loss.item()=2.243067979812622, epoch=337
# loss.item()=2.2430672645568848, epoch=338
# loss.item()=2.2430665493011475, epoch=339
# loss.item()=2.2430665493011475, epoch=340
# loss.item()=2.2430665493011475, epoch=341
# loss.item()=2.2430663108825684, epoch=342
# loss.item()=2.2430648803710938, epoch=343
# loss.item()=2.2430644035339355, epoch=344
# loss.item()=2.2430636882781982, epoch=345
# loss.item()=2.24306321144104, epoch=346
# loss.item()=2.243062973022461, epoch=347
# loss.item()=2.2430620193481445, epoch=348
# loss.item()=2.2430613040924072, epoch=349
# loss.item()=2.243060350418091, epoch=350
# loss.item()=2.2430598735809326, epoch=351
# loss.item()=2.2430593967437744, epoch=352
# loss.item()=2.2430591583251953, epoch=353
# loss.item()=2.243058204650879, epoch=354
# loss.item()=2.2430572509765625, epoch=355
# loss.item()=2.243056535720825, epoch=356
# loss.item()=2.243056058883667, epoch=357
# loss.item()=2.2430551052093506, epoch=358
# loss.item()=2.243055582046509, epoch=359
# loss.item()=2.2430546283721924, epoch=360
# loss.item()=2.243054151535034, epoch=361
# loss.item()=2.2430531978607178, epoch=362
# loss.item()=2.2430527210235596, epoch=363
# loss.item()=2.2430520057678223, epoch=364
# loss.item()=2.243051767349243, epoch=365
# loss.item()=2.2430520057678223, epoch=366
# loss.item()=2.243051767349243, epoch=367
# loss.item()=2.243051767349243, epoch=368
# loss.item()=2.243051290512085, epoch=369
# loss.item()=2.2430508136749268, epoch=370
# loss.item()=2.2430505752563477, epoch=371
# loss.item()=2.2430498600006104, epoch=372
# loss.item()=2.243048906326294, epoch=373
# loss.item()=2.2430496215820312, epoch=374
# loss.item()=2.243049383163452, epoch=375
# loss.item()=2.243049144744873, epoch=376
# loss.item()=2.243048667907715, epoch=377
# loss.item()=2.2430484294891357, epoch=378
# loss.item()=2.2430484294891357, epoch=379
# loss.item()=2.2430477142333984, epoch=380
# loss.item()=2.243046522140503, epoch=381
# loss.item()=2.2430458068847656, epoch=382
# loss.item()=2.2430450916290283, epoch=383
# loss.item()=2.243044376373291, epoch=384
# loss.item()=2.243043899536133, epoch=385
# loss.item()=2.2430436611175537, epoch=386
# loss.item()=2.2430429458618164, epoch=387
# loss.item()=2.2430429458618164, epoch=388
# loss.item()=2.2430429458618164, epoch=389
# loss.item()=2.243041753768921, epoch=390
# loss.item()=2.243041753768921, epoch=391
# loss.item()=2.2430410385131836, epoch=392
# loss.item()=2.2430408000946045, epoch=393
# loss.item()=2.243039608001709, epoch=394
# loss.item()=2.243039608001709, epoch=395
# loss.item()=2.24303936958313, epoch=396
# loss.item()=2.2430386543273926, epoch=397
# loss.item()=2.2430381774902344, epoch=398
# loss.item()=2.243037223815918, epoch=399
# loss.item()=2.243036985397339, epoch=400
# loss.item()=2.2430367469787598, epoch=401
# loss.item()=2.2430362701416016, epoch=402
# loss.item()=2.243034601211548, epoch=403
# loss.item()=2.2430343627929688, epoch=404
# loss.item()=2.243035078048706, epoch=405
# loss.item()=2.243034839630127, epoch=406
# loss.item()=2.2430336475372314, epoch=407
# loss.item()=2.2430334091186523, epoch=408
# loss.item()=2.243032932281494, epoch=409
# loss.item()=2.243032693862915, epoch=410
# loss.item()=2.2430317401885986, epoch=411
# loss.item()=2.2430310249328613, epoch=412
# loss.item()=2.2430310249328613, epoch=413
# loss.item()=2.243030548095703, epoch=414
# loss.item()=2.243030071258545, epoch=415
# loss.item()=2.2430295944213867, epoch=416
# loss.item()=2.2430295944213867, epoch=417
# loss.item()=2.2430291175842285, epoch=418
# loss.item()=2.2430286407470703, epoch=419
# loss.item()=2.2430286407470703, epoch=420
# loss.item()=2.243028163909912, epoch=421
# loss.item()=2.243027925491333, epoch=422
# loss.item()=2.2430272102355957, epoch=423
# loss.item()=2.2430269718170166, epoch=424
# loss.item()=2.2430267333984375, epoch=425
# loss.item()=2.243025779724121, epoch=426
# loss.item()=2.243025302886963, epoch=427
# loss.item()=2.2430248260498047, epoch=428
# loss.item()=2.2430238723754883, epoch=429
# loss.item()=2.243023633956909, epoch=430
# loss.item()=2.243022918701172, epoch=431
# loss.item()=2.2430226802825928, epoch=432
# loss.item()=2.2430219650268555, epoch=433
# loss.item()=2.2430217266082764, epoch=434
# loss.item()=2.243021011352539, epoch=435
# loss.item()=2.243021011352539, epoch=436
# loss.item()=2.24302077293396, epoch=437
# loss.item()=2.2430200576782227, epoch=438
# loss.item()=2.2430191040039062, epoch=439
# loss.item()=2.243018627166748, epoch=440
# loss.item()=2.24301815032959, epoch=441
# loss.item()=2.2430179119110107, epoch=442
# loss.item()=2.2430176734924316, epoch=443
# loss.item()=2.243016004562378, epoch=444
# loss.item()=2.2430152893066406, epoch=445
# loss.item()=2.2430152893066406, epoch=446
# loss.item()=2.2430152893066406, epoch=447
# loss.item()=2.2430150508880615, epoch=448
# loss.item()=2.243014335632324, epoch=449
# loss.item()=2.243013858795166, epoch=450
# loss.item()=2.2430129051208496, epoch=451
# loss.item()=2.2430124282836914, epoch=452
# loss.item()=2.243011951446533, epoch=453
# loss.item()=2.243011713027954, epoch=454
# loss.item()=2.243010997772217, epoch=455
# loss.item()=2.2430105209350586, epoch=456
# loss.item()=2.2430098056793213, epoch=457
# loss.item()=2.243009567260742, epoch=458
# loss.item()=2.243008852005005, epoch=459
# loss.item()=2.2430078983306885, epoch=460
# loss.item()=2.2430076599121094, epoch=461
# loss.item()=2.243006944656372, epoch=462
# loss.item()=2.243006706237793, epoch=463
# loss.item()=2.2430062294006348, epoch=464
# loss.item()=2.243004083633423, epoch=465
# loss.item()=2.24300217628479, epoch=466
# loss.item()=2.24300217628479, epoch=467
# loss.item()=2.243001699447632, epoch=468
# loss.item()=2.2430007457733154, epoch=469
# loss.item()=2.2430007457733154, epoch=470
# loss.item()=2.2430002689361572, epoch=471
# loss.item()=2.2430002689361572, epoch=472
# loss.item()=2.242999792098999, epoch=473
# loss.item()=2.2429981231689453, epoch=474
# loss.item()=2.2429981231689453, epoch=475
# loss.item()=2.242997884750366, epoch=476
# loss.item()=2.24299693107605, epoch=477
# loss.item()=2.2429964542388916, epoch=478
# loss.item()=2.2429959774017334, epoch=479
# loss.item()=2.242995500564575, epoch=480
# loss.item()=2.2429943084716797, epoch=481
# loss.item()=2.2429940700531006, epoch=482
# loss.item()=2.242992877960205, epoch=483
# loss.item()=2.2429921627044678, epoch=484
# loss.item()=2.2429919242858887, epoch=485
# loss.item()=2.2429916858673096, epoch=486
# loss.item()=2.2429914474487305, epoch=487
# loss.item()=2.2429909706115723, epoch=488
# loss.item()=2.2429909706115723, epoch=489
# loss.item()=2.242990493774414, epoch=490
# loss.item()=2.2429897785186768, epoch=491
# loss.item()=2.2429893016815186, epoch=492
# loss.item()=2.2429888248443604, epoch=493
# loss.item()=2.242988109588623, epoch=494
# loss.item()=2.242987871170044, epoch=495
# loss.item()=2.242987632751465, epoch=496
# loss.item()=2.2429871559143066, epoch=497
# loss.item()=2.2429864406585693, epoch=498
# loss.item()=2.242985963821411, epoch=499
# loss.item()=2.2429845333099365, epoch=500
# loss.item()=2.2429845333099365, epoch=501
# loss.item()=2.242983341217041, epoch=502
# loss.item()=2.242983341217041, epoch=503
# loss.item()=2.242983102798462, epoch=504
# loss.item()=2.2429816722869873, epoch=505
# loss.item()=2.242980718612671, epoch=506
# loss.item()=2.242981195449829, epoch=507
# loss.item()=2.242980718612671, epoch=508
# loss.item()=2.2429802417755127, epoch=509
# loss.item()=2.2429800033569336, epoch=510
# loss.item()=2.2429795265197754, epoch=511
# loss.item()=2.2429797649383545, epoch=512
# loss.item()=2.242978811264038, epoch=513
# loss.item()=2.242978572845459, epoch=514
# loss.item()=2.2429776191711426, epoch=515
# loss.item()=2.2429769039154053, epoch=516
# loss.item()=2.242976188659668, epoch=517
# loss.item()=2.242975950241089, epoch=518
# loss.item()=2.2429752349853516, epoch=519
# loss.item()=2.2429752349853516, epoch=520
# loss.item()=2.242974281311035, epoch=521
# loss.item()=2.242974042892456, epoch=522
# loss.item()=2.242973566055298, epoch=523
# loss.item()=2.2429728507995605, epoch=524
# loss.item()=2.2429723739624023, epoch=525
# loss.item()=2.242971658706665, epoch=526
# loss.item()=2.2429709434509277, epoch=527
# loss.item()=2.2429709434509277, epoch=528
# loss.item()=2.2429704666137695, epoch=529
# loss.item()=2.2429699897766113, epoch=530
# loss.item()=2.242969274520874, epoch=531
# loss.item()=2.2429685592651367, epoch=532
# loss.item()=2.2429676055908203, epoch=533
# loss.item()=2.2429676055908203, epoch=534
# loss.item()=2.242967128753662, epoch=535
# loss.item()=2.242966651916504, epoch=536
# loss.item()=2.242966651916504, epoch=537
# loss.item()=2.242966651916504, epoch=538
# loss.item()=2.242966413497925, epoch=539
# loss.item()=2.2429661750793457, epoch=540
# loss.item()=2.242964267730713, epoch=541
# loss.item()=2.242964029312134, epoch=542
# loss.item()=2.2429633140563965, epoch=543
# loss.item()=2.2429628372192383, epoch=544
# loss.item()=2.24296236038208, epoch=545
# loss.item()=2.2429616451263428, epoch=546
# loss.item()=2.2429614067077637, epoch=547
# loss.item()=2.2429606914520264, epoch=548
# loss.item()=2.2429609298706055, epoch=549
# loss.item()=2.242959499359131, epoch=550
# loss.item()=2.242959976196289, epoch=551
# loss.item()=2.242959976196289, epoch=552
# loss.item()=2.242959499359131, epoch=553
# loss.item()=2.2429590225219727, epoch=554
# loss.item()=2.2429585456848145, epoch=555
# loss.item()=2.2429580688476562, epoch=556
# loss.item()=2.242957830429077, epoch=557
# loss.item()=2.242957592010498, epoch=558
# loss.item()=2.2429566383361816, epoch=559
# loss.item()=2.2429559230804443, epoch=560
# loss.item()=2.2429559230804443, epoch=561
# loss.item()=2.242955446243286, epoch=562
# loss.item()=2.242955446243286, epoch=563
# loss.item()=2.242955207824707, epoch=564
# loss.item()=2.242954730987549, epoch=565
# loss.item()=2.2429544925689697, epoch=566
# loss.item()=2.2429537773132324, epoch=567
# loss.item()=2.2429542541503906, epoch=568
# loss.item()=2.242953300476074, epoch=569
# loss.item()=2.242952823638916, epoch=570
# loss.item()=2.242952585220337, epoch=571
# loss.item()=2.2429516315460205, epoch=572
# loss.item()=2.2429513931274414, epoch=573
# loss.item()=2.242950439453125, epoch=574
# loss.item()=2.242949962615967, epoch=575
# loss.item()=2.2429494857788086, epoch=576
# loss.item()=2.2429490089416504, epoch=577
# loss.item()=2.242948055267334, epoch=578
# loss.item()=2.242947578430176, epoch=579
# loss.item()=2.2429471015930176, epoch=580
# loss.item()=2.2429466247558594, epoch=581
# loss.item()=2.2429463863372803, epoch=582
# loss.item()=2.242946147918701, epoch=583
# loss.item()=2.2429449558258057, epoch=584
# loss.item()=2.2429447174072266, epoch=585
# loss.item()=2.24294376373291, epoch=586
# loss.item()=2.242943525314331, epoch=587
# loss.item()=2.242943048477173, epoch=588
# loss.item()=2.242943048477173, epoch=589
# loss.item()=2.2429425716400146, epoch=590
# loss.item()=2.242941379547119, epoch=591
# loss.item()=2.24294114112854, epoch=592
# loss.item()=2.242940664291382, epoch=593
# loss.item()=2.2429397106170654, epoch=594
# loss.item()=2.2429392337799072, epoch=595
# loss.item()=2.24293851852417, epoch=596
# loss.item()=2.2429380416870117, epoch=597
# loss.item()=2.242938280105591, epoch=598
# loss.item()=2.242938280105591, epoch=599
# loss.item()=2.2429380416870117, epoch=600
# loss.item()=2.2429373264312744, epoch=601
# loss.item()=2.2429373264312744, epoch=602
# loss.item()=2.2429370880126953, epoch=603
# loss.item()=2.242936611175537, epoch=604
# loss.item()=2.2429358959198, epoch=605
# loss.item()=2.2429354190826416, epoch=606
# loss.item()=2.2429349422454834, epoch=607
# loss.item()=2.2429347038269043, epoch=608
# loss.item()=2.2429347038269043, epoch=609
# loss.item()=2.242934465408325, epoch=610
# loss.item()=2.242934465408325, epoch=611
# loss.item()=2.242933750152588, epoch=612
# loss.item()=2.2429330348968506, epoch=613
# loss.item()=2.242932081222534, epoch=614
# loss.item()=2.242931365966797, epoch=615
# loss.item()=2.2429311275482178, epoch=616
# loss.item()=2.2429306507110596, epoch=617
# loss.item()=2.2429301738739014, epoch=618
# loss.item()=2.2429287433624268, epoch=619
# loss.item()=2.2429287433624268, epoch=620
# loss.item()=2.2429277896881104, epoch=621
# loss.item()=2.242926836013794, epoch=622
# loss.item()=2.242927074432373, epoch=623
# loss.item()=2.242926836013794, epoch=624
# loss.item()=2.2429263591766357, epoch=625
# loss.item()=2.2429256439208984, epoch=626
# loss.item()=2.2429256439208984, epoch=627
# loss.item()=2.2429251670837402, epoch=628
# loss.item()=2.242924451828003, epoch=629
# loss.item()=2.242924451828003, epoch=630
# loss.item()=2.242924451828003, epoch=631
# loss.item()=2.2429230213165283, epoch=632
# loss.item()=2.242922782897949, epoch=633
# loss.item()=2.24292254447937, epoch=634
# loss.item()=2.242922067642212, epoch=635
# loss.item()=2.2429213523864746, epoch=636
# loss.item()=2.2429206371307373, epoch=637
# loss.item()=2.242920160293579, epoch=638
# loss.item()=2.242919683456421, epoch=639
# loss.item()=2.242919683456421, epoch=640
# loss.item()=2.2429187297821045, epoch=641
# loss.item()=2.2429182529449463, epoch=642
# loss.item()=2.24291729927063, epoch=643
# loss.item()=2.242917060852051, epoch=644
# loss.item()=2.2429165840148926, epoch=645
# loss.item()=2.2429163455963135, epoch=646
# loss.item()=2.2429161071777344, epoch=647
# loss.item()=2.242915630340576, epoch=648
# loss.item()=2.2429146766662598, epoch=649
# loss.item()=2.2429144382476807, epoch=650
# loss.item()=2.2429139614105225, epoch=651
# loss.item()=2.242913246154785, epoch=652
# loss.item()=2.242913007736206, epoch=653
# loss.item()=2.2429118156433105, epoch=654
# loss.item()=2.2429113388061523, epoch=655
# loss.item()=2.2429113388061523, epoch=656
# loss.item()=2.242910861968994, epoch=657
# loss.item()=2.242910861968994, epoch=658
# loss.item()=2.242910385131836, epoch=659
# loss.item()=2.2429091930389404, epoch=660
# loss.item()=2.2429091930389404, epoch=661
# loss.item()=2.242907762527466, epoch=662
# loss.item()=2.2429072856903076, epoch=663
# loss.item()=2.2429068088531494, epoch=664
# loss.item()=2.242905616760254, epoch=665
# loss.item()=2.2429051399230957, epoch=666
# loss.item()=2.2429044246673584, epoch=667
# loss.item()=2.2429039478302, epoch=668
# loss.item()=2.2429027557373047, epoch=669
# loss.item()=2.2429025173187256, epoch=670
# loss.item()=2.242901563644409, epoch=671
# loss.item()=2.24290132522583, epoch=672
# loss.item()=2.242901086807251, epoch=673
# loss.item()=2.2429001331329346, epoch=674
# loss.item()=2.2428994178771973, epoch=675
# loss.item()=2.242898941040039, epoch=676
# loss.item()=2.24289870262146, epoch=677
# loss.item()=2.2428982257843018, epoch=678
# loss.item()=2.2428972721099854, epoch=679
# loss.item()=2.2428970336914062, epoch=680
# loss.item()=2.242896556854248, epoch=681
# loss.item()=2.242896318435669, epoch=682
# loss.item()=2.24289608001709, epoch=683
# loss.item()=2.2428953647613525, epoch=684
# loss.item()=2.2428951263427734, epoch=685
# loss.item()=2.2428948879241943, epoch=686
# loss.item()=2.2428951263427734, epoch=687
# loss.item()=2.2428946495056152, epoch=688
# loss.item()=2.242894172668457, epoch=689
# loss.item()=2.2428932189941406, epoch=690
# loss.item()=2.2428929805755615, epoch=691
# loss.item()=2.242892265319824, epoch=692
# loss.item()=2.242892026901245, epoch=693
# loss.item()=2.2428927421569824, epoch=694
# loss.item()=2.242892026901245, epoch=695
# loss.item()=2.242891788482666, epoch=696
# loss.item()=2.242891311645508, epoch=697
# loss.item()=2.2428908348083496, epoch=698
# loss.item()=2.2428908348083496, epoch=699
# loss.item()=2.2428905963897705, epoch=700
# loss.item()=2.2428903579711914, epoch=701
# loss.item()=2.242889404296875, epoch=702
# loss.item()=2.242889165878296, epoch=703
# loss.item()=2.2428884506225586, epoch=704
# loss.item()=2.2428879737854004, epoch=705
# loss.item()=2.242886781692505, epoch=706
# loss.item()=2.2428863048553467, epoch=707
# loss.item()=2.2428858280181885, epoch=708
# loss.item()=2.2428855895996094, epoch=709
# loss.item()=2.2428853511810303, epoch=710
# loss.item()=2.2428841590881348, epoch=711
# loss.item()=2.2428839206695557, epoch=712
# loss.item()=2.2428836822509766, epoch=713
# loss.item()=2.2428832054138184, epoch=714
# loss.item()=2.2428832054138184, epoch=715
# loss.item()=2.242882490158081, epoch=716
# loss.item()=2.242882013320923, epoch=717
# loss.item()=2.2428810596466064, epoch=718
# loss.item()=2.242880344390869, epoch=719
# loss.item()=2.242879867553711, epoch=720
# loss.item()=2.2428789138793945, epoch=721
# loss.item()=2.2428793907165527, epoch=722
# loss.item()=2.2428789138793945, epoch=723
# loss.item()=2.2428781986236572, epoch=724
# loss.item()=2.242877960205078, epoch=725
# loss.item()=2.242877721786499, epoch=726
# loss.item()=2.242877244949341, epoch=727
# loss.item()=2.242877244949341, epoch=728
# loss.item()=2.2428762912750244, epoch=729
# loss.item()=2.242875814437866, epoch=730
# loss.item()=2.24287486076355, epoch=731
# loss.item()=2.2428743839263916, epoch=732
# loss.item()=2.2428743839263916, epoch=733
# loss.item()=2.242871046066284, epoch=734
# loss.item()=2.242870807647705, epoch=735
# loss.item()=2.2428698539733887, epoch=736
# loss.item()=2.2428691387176514, epoch=737
# loss.item()=2.242868661880493, epoch=738
# loss.item()=2.242868423461914, epoch=739
# loss.item()=2.2428677082061768, epoch=740
# loss.item()=2.2428674697875977, epoch=741
# loss.item()=2.2428669929504395, epoch=742
# loss.item()=2.242866277694702, epoch=743
# loss.item()=2.242866039276123, epoch=744
# loss.item()=2.2428650856018066, epoch=745
# loss.item()=2.242863416671753, epoch=746
# loss.item()=2.2428629398345947, epoch=747
# loss.item()=2.2428627014160156, epoch=748
# loss.item()=2.2428624629974365, epoch=749
# loss.item()=2.2428624629974365, epoch=750
# loss.item()=2.2428619861602783, epoch=751
# loss.item()=2.2428619861602783, epoch=752
# loss.item()=2.2428619861602783, epoch=753
# loss.item()=2.2428619861602783, epoch=754
# loss.item()=2.2428619861602783, epoch=755
# loss.item()=2.24286150932312, epoch=756
# loss.item()=2.2428605556488037, epoch=757
# loss.item()=2.2428605556488037, epoch=758
# loss.item()=2.2428596019744873, epoch=759
# loss.item()=2.24285888671875, epoch=760
# loss.item()=2.2428572177886963, epoch=761
# loss.item()=2.242856502532959, epoch=762
# loss.item()=2.24285626411438, epoch=763
# loss.item()=2.242856502532959, epoch=764
# loss.item()=2.2428553104400635, epoch=765
# loss.item()=2.2428548336029053, epoch=766
# loss.item()=2.2428548336029053, epoch=767
# loss.item()=2.2428553104400635, epoch=768
# loss.item()=2.2428548336029053, epoch=769
# loss.item()=2.2428548336029053, epoch=770
# loss.item()=2.242854595184326, epoch=771
# loss.item()=2.242854356765747, epoch=772
# loss.item()=2.2428534030914307, epoch=773
# loss.item()=2.2428526878356934, epoch=774
# loss.item()=2.242851972579956, epoch=775
# loss.item()=2.242851972579956, epoch=776
# loss.item()=2.2428524494171143, epoch=777
# loss.item()=2.242851734161377, epoch=778
# loss.item()=2.2428510189056396, epoch=779
# loss.item()=2.2428507804870605, epoch=780
# loss.item()=2.242849588394165, epoch=781
# loss.item()=2.242849111557007, epoch=782
# loss.item()=2.2428488731384277, epoch=783
# loss.item()=2.2428483963012695, epoch=784
# loss.item()=2.2428483963012695, epoch=785
# loss.item()=2.2428481578826904, epoch=786
# loss.item()=2.2428479194641113, epoch=787
# loss.item()=2.242847442626953, epoch=788
# loss.item()=2.2428460121154785, epoch=789
# loss.item()=2.2428460121154785, epoch=790
# loss.item()=2.2428455352783203, epoch=791
# loss.item()=2.242844820022583, epoch=792
# loss.item()=2.2428441047668457, epoch=793
# loss.item()=2.2428441047668457, epoch=794
# loss.item()=2.2428441047668457, epoch=795
# loss.item()=2.2428433895111084, epoch=796
# loss.item()=2.242842674255371, epoch=797
# loss.item()=2.242842674255371, epoch=798
# loss.item()=2.242842674255371, epoch=799
# loss.item()=2.2428414821624756, epoch=800
# loss.item()=2.2428412437438965, epoch=801
# loss.item()=2.2428407669067383, epoch=802
# loss.item()=2.24284029006958, epoch=803
# loss.item()=2.24284029006958, epoch=804
# loss.item()=2.242839813232422, epoch=805
# loss.item()=2.2428395748138428, epoch=806
# loss.item()=2.2428393363952637, epoch=807
# loss.item()=2.2428388595581055, epoch=808
# loss.item()=2.2428388595581055, epoch=809
# loss.item()=2.242837905883789, epoch=810
# loss.item()=2.2428371906280518, epoch=811
# loss.item()=2.2428364753723145, epoch=812
# loss.item()=2.2428359985351562, epoch=813
# loss.item()=2.242835283279419, epoch=814
# loss.item()=2.2428348064422607, epoch=815
# loss.item()=2.2428343296051025, epoch=816
# loss.item()=2.2428343296051025, epoch=817
# loss.item()=2.2428338527679443, epoch=818
# loss.item()=2.242833375930786, epoch=819
# loss.item()=2.242833137512207, epoch=820
# loss.item()=2.242832660675049, epoch=821
# loss.item()=2.242832660675049, epoch=822
# loss.item()=2.242830991744995, epoch=823
# loss.item()=2.242830276489258, epoch=824
# loss.item()=2.242830276489258, epoch=825
# loss.item()=2.2428297996520996, epoch=826
# loss.item()=2.2428297996520996, epoch=827
# loss.item()=2.2428295612335205, epoch=828
# loss.item()=2.242828845977783, epoch=829
# loss.item()=2.242828607559204, epoch=830
# loss.item()=2.242828130722046, epoch=831
# loss.item()=2.242827892303467, epoch=832
# loss.item()=2.242827892303467, epoch=833
# loss.item()=2.2428274154663086, epoch=834
# loss.item()=2.2428271770477295, epoch=835
# loss.item()=2.242826461791992, epoch=836
# loss.item()=2.242825508117676, epoch=837
# loss.item()=2.2428250312805176, epoch=838
# loss.item()=2.2428247928619385, epoch=839
# loss.item()=2.242823600769043, epoch=840
# loss.item()=2.242823600769043, epoch=841
# loss.item()=2.2428231239318848, epoch=842
# loss.item()=2.2428221702575684, epoch=843
# loss.item()=2.242821216583252, epoch=844
# loss.item()=2.2428205013275146, epoch=845
# loss.item()=2.2428202629089355, epoch=846
# loss.item()=2.2428197860717773, epoch=847
# loss.item()=2.2428197860717773, epoch=848
# loss.item()=2.2428181171417236, epoch=849
# loss.item()=2.2428176403045654, epoch=850
# loss.item()=2.2428171634674072, epoch=851
# loss.item()=2.2428159713745117, epoch=852
# loss.item()=2.242814779281616, epoch=853
# loss.item()=2.242814302444458, epoch=854
# loss.item()=2.242814064025879, epoch=855
# loss.item()=2.242814064025879, epoch=856
# loss.item()=2.2428138256073, epoch=857
# loss.item()=2.2428133487701416, epoch=858
# loss.item()=2.2428128719329834, epoch=859
# loss.item()=2.2428133487701416, epoch=860
# loss.item()=2.242812395095825, epoch=861
# loss.item()=2.242811441421509, epoch=862
# loss.item()=2.2428109645843506, epoch=863
# loss.item()=2.2428107261657715, epoch=864
# loss.item()=2.242809772491455, epoch=865
# loss.item()=2.2428090572357178, epoch=866
# loss.item()=2.2428090572357178, epoch=867
# loss.item()=2.2428085803985596, epoch=868
# loss.item()=2.2428083419799805, epoch=869
# loss.item()=2.2428078651428223, epoch=870
# loss.item()=2.2428066730499268, epoch=871
# loss.item()=2.2428064346313477, epoch=872
# loss.item()=2.2428057193756104, epoch=873
# loss.item()=2.242804765701294, epoch=874
# loss.item()=2.2428042888641357, epoch=875
# loss.item()=2.2428038120269775, epoch=876
# loss.item()=2.2428035736083984, epoch=877
# loss.item()=2.242802619934082, epoch=878
# loss.item()=2.242802381515503, epoch=879
# loss.item()=2.2428019046783447, epoch=880
# loss.item()=2.2428016662597656, epoch=881
# loss.item()=2.2428014278411865, epoch=882
# loss.item()=2.2428009510040283, epoch=883
# loss.item()=2.24280047416687, epoch=884
# loss.item()=2.242799758911133, epoch=885
# loss.item()=2.2427988052368164, epoch=886
# loss.item()=2.2427985668182373, epoch=887
# loss.item()=2.242798328399658, epoch=888
# loss.item()=2.242797374725342, epoch=889
# loss.item()=2.2427968978881836, epoch=890
# loss.item()=2.242795944213867, epoch=891
# loss.item()=2.242795944213867, epoch=892
# loss.item()=2.242795705795288, epoch=893
# loss.item()=2.24279522895813, epoch=894
# loss.item()=2.2427942752838135, epoch=895
# loss.item()=2.2427937984466553, epoch=896
# loss.item()=2.242793321609497, epoch=897
# loss.item()=2.242792844772339, epoch=898
# loss.item()=2.2427923679351807, epoch=899
# loss.item()=2.2427921295166016, epoch=900
# loss.item()=2.2427918910980225, epoch=901
# loss.item()=2.2427921295166016, epoch=902
# loss.item()=2.2427914142608643, epoch=903
# loss.item()=2.242790937423706, epoch=904
# loss.item()=2.242790460586548, epoch=905
# loss.item()=2.2427899837493896, epoch=906
# loss.item()=2.2427890300750732, epoch=907
# loss.item()=2.242788076400757, epoch=908
# loss.item()=2.2427875995635986, epoch=909
# loss.item()=2.2427871227264404, epoch=910
# loss.item()=2.2427868843078613, epoch=911
# loss.item()=2.242786169052124, epoch=912
# loss.item()=2.2427854537963867, epoch=913
# loss.item()=2.2427875995635986, epoch=914
# loss.item()=2.242786407470703, epoch=915
# loss.item()=2.2427895069122314, epoch=916
# loss.item()=2.2427890300750732, epoch=917
# loss.item()=2.242788553237915, epoch=918
# loss.item()=2.242788314819336, epoch=919
# loss.item()=2.242788076400757, epoch=920
# loss.item()=2.242788314819336, epoch=921
# loss.item()=2.2427878379821777, epoch=922
# loss.item()=2.2427868843078613, epoch=923
# loss.item()=2.242786407470703, epoch=924
# loss.item()=2.242786407470703, epoch=925
# loss.item()=2.242785930633545, epoch=926
# loss.item()=2.2427854537963867, epoch=927
# loss.item()=2.2427845001220703, epoch=928
# loss.item()=2.2427845001220703, epoch=929
# loss.item()=2.242784023284912, epoch=930
# loss.item()=2.242783308029175, epoch=931
# loss.item()=2.2427823543548584, epoch=932
# loss.item()=2.242781639099121, epoch=933
# loss.item()=2.242781162261963, epoch=934
# loss.item()=2.2427806854248047, epoch=935
# loss.item()=2.2427797317504883, epoch=936
# loss.item()=2.2427797317504883, epoch=937
# loss.item()=2.2427797317504883, epoch=938
# loss.item()=2.242779493331909, epoch=939
# loss.item()=2.24277925491333, epoch=940
# loss.item()=2.242778778076172, epoch=941
# loss.item()=2.2427778244018555, epoch=942
# loss.item()=2.2427761554718018, epoch=943
# loss.item()=2.2427754402160645, epoch=944
# loss.item()=2.2427735328674316, epoch=945
# loss.item()=2.2427778244018555, epoch=946
# loss.item()=2.24277400970459, epoch=947
# loss.item()=2.2427730560302734, epoch=948
# loss.item()=2.2427725791931152, epoch=949
# loss.item()=2.2427711486816406, epoch=950
# loss.item()=2.2427709102630615, epoch=951
# loss.item()=2.2427709102630615, epoch=952
# loss.item()=2.2427704334259033, epoch=953
# loss.item()=2.242769718170166, epoch=954
# loss.item()=2.242769241333008, epoch=955
# loss.item()=2.242769241333008, epoch=956
# loss.item()=2.2427685260772705, epoch=957
# loss.item()=2.2427680492401123, epoch=958
# loss.item()=2.242767810821533, epoch=959
# loss.item()=2.242767333984375, epoch=960
# loss.item()=2.242766857147217, epoch=961
# loss.item()=2.2427663803100586, epoch=962
# loss.item()=2.2427659034729004, epoch=963
# loss.item()=2.242765188217163, epoch=964
# loss.item()=2.242764949798584, epoch=965
# loss.item()=2.242764472961426, epoch=966
# loss.item()=2.2427632808685303, epoch=967
# loss.item()=2.2427635192871094, epoch=968
# loss.item()=2.242762565612793, epoch=969
# loss.item()=2.2427618503570557, epoch=970
# loss.item()=2.2427616119384766, epoch=971
# loss.item()=2.2427608966827393, epoch=972
# loss.item()=2.24276065826416, epoch=973
# loss.item()=2.242760419845581, epoch=974
# loss.item()=2.242760181427002, epoch=975
# loss.item()=2.2427592277526855, epoch=976
# loss.item()=2.2427585124969482, epoch=977
# loss.item()=2.242757797241211, epoch=978
# loss.item()=2.242757558822632, epoch=979
# loss.item()=2.2427573204040527, epoch=980
# loss.item()=2.2427568435668945, epoch=981
# loss.item()=2.2427561283111572, epoch=982
# loss.item()=2.24275541305542, epoch=983
# loss.item()=2.242755174636841, epoch=984
# loss.item()=2.2427542209625244, epoch=985
# loss.item()=2.2427542209625244, epoch=986
# loss.item()=2.242753744125366, epoch=987
# loss.item()=2.242753267288208, epoch=988
# loss.item()=2.242753028869629, epoch=989
# loss.item()=2.2427523136138916, epoch=990
# loss.item()=2.2427523136138916, epoch=991
# loss.item()=2.2427515983581543, epoch=992
# loss.item()=2.242751359939575, epoch=993
# loss.item()=2.242750644683838, epoch=994
# loss.item()=2.242750406265259, epoch=995
# loss.item()=2.2427499294281006, epoch=996
# loss.item()=2.2427494525909424, epoch=997
# loss.item()=2.2427494525909424, epoch=998
# loss.item()=2.2427494525909424, epoch=999

# %%
# predicting

g = torch.Generator().manual_seed(2147483647)

for i in range(10):
    
    ix1 = 0
    ix2 = 0
    out = []
    temperature = 0.6

    while True:

        logits = xenc @ W
        count = logits.exp()
        probs = count / count.sum(1, keepdims=True)
        p = tensor[ix1,ix2] ** (1.0/temperature)

        ix3 = torch.multinomial(p,num_samples=1,replacement=True,generator=g).item()
        if ix3 == 0:
            break
        out.append(itos[ix3])

        ix1, ix2 = ix2, ix3
        
    print(''.join(out))
# Out:
# juniden
# pracar
# pariah
# olin
# fair
# lailia
# sarie
# umanna
# uria
# len
